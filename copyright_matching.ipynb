# %%
import pandas as pd
import numpy as np
import os
from lxml import etree
from tqdm import tqdm
import re
import pickle
from uuid import uuid4
import shelve
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Parsing Copyright Registrations
#
# ### A few considerations:
#
# 1. Copyright registrations that happened after 1963 were renewed automatically, so there's no point in checking them for an explicit renewal.
#
# 2. "Every registration should have a registration number, such as A56505, but these are not unique. Numbering was restarted in 'Third Series' (1947–) so there is quite a bit of overlap between this and the 'New Series.' For example, **a registration number and date is always required to distinguish 'A56505/1951-06-06' from 'A56505/1932-10-12'**."
#
# 3. "The *duplicateOf* attribute indicates that the entry with the attribute contains the same information as the entry it points to and adds nothing to it. They must both have identical registration numbers and dates. \[\.\.\.\] All other things being equal, later duplicates should refer to earlier entries. If there are multiple duplications all duplicates should point to the same "master" registration. That entry must not have a *duplicateOf* attribute. So, **when processing, any entries carrying a *duplicateOf* attribute can be skipped, since -- if an entry is truly a duplicate -- it adds nothing the copyright history of the work.** When importing into a database, this will assure that there is only one row with the registration number/date combination. **Renewals should be linked to registrations without the *duplicateOf* attribute.**
#
# 4. Some of the registration records are foreign/interim registrations (AF and AI), which aren't subject to the normal renewal rules. These should be removed.

# %%
# load up directory of copyright registrations coded in XML

base_path = os.getcwd()

registration_files = os.path.join(base_path, 'catalog_of_copyright_entries_project-master', 'xml')

reg_directories = [x for x in os.listdir(registration_files)]

xml_data = []
for directory in tqdm(reg_directories):
    # Copyright registrations that happened after 1963 were renewed automatically,
    # so there's no point in checking them for an explicit renewal.
    if int(directory) > 1963:
        pass
    else:
        files = [x for x in os.listdir(os.path.join(registration_files, directory)) if x[-4:] == '.xml']
        for file in files:
            tree = etree.parse(os.path.join(registration_files, directory, file))
            root = tree.getroot()
            entries = root.findall('copyrightEntry')
            for entry in entries:
                # any entries carrying a *duplicateOf* attribute can be skipped
                if 'duplicateOf' in entry.attrib:
                    pass
                else:
                    try:
                        regnum = entry.attrib['regnum']
                    except:
                        regnum = 'ERROR'
                    try:
                        ident = entry.attrib['id']
                    except:
                        ident = 'ERROR'
                    temp = {'control_number': regnum, 'id': ident, 'xml_year': directory}
                    for child in entry:
                        if child.tag == 'regDate':
                            try:
                                temp['control_date'] = child.attrib['date']
                                temp['regDate'] = child.text
                            except KeyError:
                                temp['control_date'] = 'ERROR'
                                temp['regDate'] = child.text
                        elif child.tag == 'regdate':
                            try:
                                temp['control_date'] = child.attrib['date']
                                temp['regDate'] = child.text
                            except KeyError:
                                temp['control_date'] = 'ERROR'
                                temp['regDate'] = child.text
                        else:
                            temp[child.tag] = child.text
                    xml_data.append(temp)
# Out:
# 100%|██████████| 46/46 [00:15<00:00,  2.94it/s]

# %%
# create dataframe (DF) of parsed registrations
registrations_df = pd.DataFrame(xml_data).set_index('id')
len(registrations_df)
# Out:
# 711409

# %%
# how many are international/interim copyrights?
len(registrations_df[(registrations_df['control_number'].str.contains('AI', case=True, regex=False)) |
                     (registrations_df['control_number'].str.contains('AF', case=True, regex=False))])
# Out:
# 131148

# %%
# remove international/interim registrations
registrations_df = registrations_df[registrations_df['control_number'].str.contains('AI', case=True, regex=False) == False]
registrations_df = registrations_df[registrations_df['control_number'].str.contains('AF', case=True, regex=False) == False]
len(registrations_df)
# Out:
# 580261

# %%
# are any of the registrations missing a control date?
len(registrations_df[registrations_df['control_date'] == 'ERROR'])
# Out:
# 1

# %%
registrations_df[registrations_df['control_date'] == 'ERROR']
# Out:
#                                      control_number xml_year    author  \
# id
# 5A28A65B-6E24-1014-A696-AD35B3FDE14F          A6151     1946  author,
#
#                                                      title edition publisher  \
# id
# 5A28A65B-6E24-1014-A696-AD35B3FDE14F  Mine own executioner     NaN      None
#
#                                                              desc  \
# id
# 5A28A65B-6E24-1014-A696-AD35B3FDE14F  xiv p., 1 l., 336 p. 21½ͨͫ.
#
#                                      control_date  regDate copies copyDate  \
# id
# 5A28A65B-6E24-1014-A696-AD35B3FDE14F        ERROR  10Sep46     2c  29Aug46
#
#                                      affDate regNum      lccn  \
# id
# 5A28A65B-6E24-1014-A696-AD35B3FDE14F     NaN  A6151  46-11904
#
#                                                                                    note  \
# id
# 5A28A65B-6E24-1014-A696-AD35B3FDE14F  "First printed in the United States, 1946." I....
#
#                                      newMatterClaimed series  vol volumes  \
# id
# 5A28A65B-6E24-1014-A696-AD35B3FDE14F              NaN    NaN  NaN     NaN
#
#                                      claimant prevPub additionalEntry  \
# id
# 5A28A65B-6E24-1014-A696-AD35B3FDE14F      NaN     NaN             NaN
#
#                                               prev-regNum noticeDate role
# id
# 5A28A65B-6E24-1014-A696-AD35B3FDE14F  Prev. reg. AI 29232        NaN  NaN

# %%
# fill in that date from regDate
registrations_df.at['5A28A65B-6E24-1014-A696-AD35B3FDE14F', 'control_date'] = '1946-09-10'

# %%
# are any of the registrations missing a control number?
len(registrations_df[(registrations_df['control_number'] == 'ERROR')])
# Out:
# 158

# %%
# check to see if missing control numbers equals the same number in the regNum field
len(registrations_df[(registrations_df['control_number'] == 'ERROR') & (registrations_df['regNum'].isnull())])
# Out:
# 157

# %%
# apparently there's one outlier:
registrations_df[(registrations_df['control_number'] == 'ERROR') & (registrations_df['regNum'].notnull())]
# Out:
#                                      control_number xml_year author  \
# id
# 0BFA5A57-79D5-1014-8221-AE20959418B2          ERROR     1948   None
#
#                                                                      title  \
# id
# 0BFA5A57-79D5-1014-8221-AE20959418B2  J. E. Klingberg, adventurer in faith
#
#                                      edition publisher           desc  \
# id
# 0BFA5A57-79D5-1014-8221-AE20959418B2     NaN      None  200 p. illus.
#
#                                      control_date  regDate copies copyDate  \
# id
# 0BFA5A57-79D5-1014-8221-AE20959418B2   1948-12-15  15Dec48    NaN      NaN
#
#                                      affDate  regNum lccn         note  \
# id
# 0BFA5A57-79D5-1014-8221-AE20959418B2     NaN  A28518  NaN  a biography
#
#                                      newMatterClaimed  \
# id
# 0BFA5A57-79D5-1014-8221-AE20959418B2              NaN
#
#                                                                                  series  \
# id
# 0BFA5A57-79D5-1014-8221-AE20959418B2  [Baptist General Conference of America] Centen...
#
#                                       vol volumes claimant prevPub  \
# id
# 0BFA5A57-79D5-1014-8221-AE20959418B2  NaN     NaN      NaN     NaN
#
#                                      additionalEntry prev-regNum noticeDate  \
# id
# 0BFA5A57-79D5-1014-8221-AE20959418B2             NaN         NaN        NaN
#
#                                      role
# id
# 0BFA5A57-79D5-1014-8221-AE20959418B2  NaN

# %%
# fill in that control number from regNum
registrations_df.at['0BFA5A57-79D5-1014-8221-AE20959418B2', 'control_number'] = 'A28518'

# %%
# what about control numbers that, uh, aren't control numbers?
(registrations_df.sort_values(by=['control_number'], ascending=False)).head(15)
# Out:
#                                        control_number xml_year author  \
# id
# 7EE3500E-6E18-1014-9400-B664922230AB            no. 8     1942    NaN
# 7F934843-6E18-1014-9400-B664922230AB         no. 5288     1942    NaN
# 7D944988-6E18-1014-9400-B664922230AB         no. 5261     1942    NaN
# 7F2608C3-6E18-1014-9400-B664922230AB            no. 4     1942    NaN
# 7F3396D2-6E18-1014-9400-B664922230AB            no. 4     1942    NaN
# 7F0C9288-6E18-1014-9400-B664922230AB          no. 172     1942    NaN
# 7D90C472-6E18-1014-9400-B664922230AB           no. 12     1942    NaN
# 9B0B664D-6D0F-1014-9803-8BC52073E431  l4Aug59 A404569     1959   None
# 74C5BB13-6E97-1014-9357-E9A0C844EAF1            c1952     1952   None
# D0F4FB38-6D0A-1014-853A-B63123D40E62            c1946     1947   None
# 65934EB9-6E24-1014-A696-AD35B3FDE14F            c1946     1946    NaN
# F589B7BA-6D13-1014-B63C-9736EB68D6D
aN
# 9B0B664D-6D0F-1014-9803-8BC52073E431                                                NaN
# 74C5BB13-6E97-1014-9357-E9A0C844EAF1                                                NaN
# D0F4FB38-6D0A-1014-853A-B63123D40E62  Text in Hebrew; title transliterated. Previous...
# 65934EB9-6E24-1014-A696-AD35B3FDE14F                                                NaN
# F589B7BA-6D13-1014-B63C-9736EB68D6D5                                                NaN
# 05E3281B-6D14-1014-B63C-9736EB68D6D5                                                NaN
# 1AEF60A2-7289-1014-A093-F050B7410E2F                                                NaN
# BEE1E610-6D17-1014-B416-88728C01EDA4                                                NaN
#
#                                      newMatterClaimed            series  \
# id
# 7EE3500E-6E18-1014-9400-B664922230AB              NaN               NaN
# 7F934843-6E18-1014-9400-B664922230AB              NaN               NaN
# 7D944988-6E18-1014-9400-B664922230AB              NaN               NaN
# 7F2608C3-6E18-1014-9400-B664922230AB              NaN               NaN
# 7F3396D2-6E18-1014-9400-B664922230AB              NaN               NaN
# 7F0C9288-6E18-1014-9400-B664922230AB              NaN               NaN
# 7D90C472-6E18-1014-9400-B664922230AB              NaN               NaN
# 9B0B664D-6D0F-1014-9803-8BC52073E431              NaN               NaN
# 74C5BB13-6E97-1014-9357-E9A0C844EAF1              NaN               NaN
# D0F4FB38-6D0A-1014-853A-B63123D40E62              NaN               NaN
# 65934EB9-6E24-1014-A696-AD35B3FDE14F              NaN               NaN
# F589B7BA-6D13-1014-B63C-9736EB68D6D5              NaN               NaN
# 05E3281B-6D14-1014-B63C-9736EB68D6D5              NaN  (Lilli-An Wills)
# 1AEF60A2-7289-1014-A093-F050B7410E2F              NaN               NaN
# BEE1E610-6D17-1014-B416-88728C01EDA4              NaN               NaN
#
#                                          vol volumes claimant prevPub  \
# id
# 7EE3500E-6E18-1014-9400-B664922230AB   v. 14     NaN      NaN     NaN
# 7F934843-6E18-1014-9400-B664922230AB  v. 202     NaN      NaN     NaN
# 7D944988-6E18-1014-9400-B664922230AB  v. 201     NaN      NaN     NaN
# 7F2608C3-6E18-1014-9400-B664922230AB    v. 9     NaN      NaN     NaN
# 7F3396D2-6E18-1014-9400-B664922230AB   v. 13     NaN      NaN     NaN
# 7F0C9288-6E18-1014-9400-B664922230AB   v. 16     NaN      NaN     NaN
# 7D90C472-6E18-1014-9400-B664922230AB   v. 12     NaN      NaN     NaN
# 9B0B664D-6D0F-1014-9803-8BC52073E431     NaN     NaN      NaN     NaN
# 74C5BB13-6E97-1014-9357-E9A0C844EAF1     NaN     NaN      NaN     NaN
# D0F4FB38-6D0A-1014-853A-B63123D40E62     NaN     NaN      NaN     NaN
# 65934EB9-6E24-1014-A696-AD35B3FDE14F     NaN     1 v      NaN     NaN
# F589B7BA-6D13-1014-B63C-9736EB68D6D5     NaN     NaN      NaN     NaN
# 05E3281B-6D14-1014-B63C-9736EB68D6D5     NaN     NaN      NaN     NaN
# 1AEF60A2-7289-1014-A093-F050B7410E2F     NaN     NaN      NaN     NaN
# BEE1E610-6D17-1014-B416-88728C01EDA4     NaN     NaN      NaN     NaN
#
#                                      additionalEntry prev-regNum noticeDate  \
# id
# 7EE3500E-6E18-1014-9400-B664922230AB             NaN         NaN        NaN
# 7F934843-6E18-1014-9400-B664922230AB       No. 5297,         NaN        NaN
# 7D944988-6E18-1014-9400-B664922230AB                         NaN        NaN
# 7F2608C3-6E18-1014-9400-B664922230AB                         NaN        NaN
# 7F3396D2-6E18-1014-9400-B664922230AB        No. 13,          NaN        NaN
# 7F0C9288-6E18-1014-9400-B664922230AB             NaN         NaN        NaN
# 7D90C472-6E18-1014-9400-B664922230AB         No. 7,          NaN        NaN
# 9B0B664D-6D0F-1014-9803-8BC52073E431             NaN         NaN        NaN
# 74C5BB13-6E97-1014-9357-E9A0C844EAF1             NaN         NaN        NaN
# D0F4FB38-6D0A-1014-853A-B63123D40E62             NaN         NaN        NaN
# 65934EB9-6E24-1014-A696-AD35B3FDE14F             NaN         NaN        NaN
# F589B7BA-6D13-1014-B63C-9736EB68D6D5             NaN         NaN        NaN
# 05E3281B-6D14-1014-B63C-9736EB68D6D5             NaN         NaN        NaN
# 1AEF60A2-7289-1014-A093-F050B7410E2F             NaN         NaN        NaN
# BEE1E610-6D17-1014-B416-88728C01EDA4             NaN         NaN        NaN
#
#                                      role
# id
# 7EE3500E-6E18-1014-9400-B664922230AB  NaN
# 7F934843-6E18-1014-9400-B664922230AB  NaN
# 7D944988-6E18-1014-9400-B664922230AB  NaN
# 7F2608C3-6E18-1014-9400-B664922230AB  NaN
# 7F3396D2-6E18-1014-9400-B664922230AB  NaN
# 7F0C9288-6E18-1014-9400-B664922230AB  NaN
# 7D90C472-6E18-1014-9400-B664922230AB  NaN
# 9B0B664D-6D0F-1014-9803-8BC52073E431  NaN
# 74C5BB13-6E97-1014-9357-E9A0C844EAF1  NaN
# D0F4FB38-6D0A-1014-853A-B63123D40E62  NaN
# 65934EB9-6E24-1014-A696-AD35B3FDE14F  NaN
# F589B7BA-6D13-1014-B63C-9736EB68D6D5  NaN
# 05E3281B-6D14-1014-B63C-9736EB68D6D5  NaN
# 1AEF60A2-7289-1014-A093-F050B7410E2F  NaN
# BEE1E610-6D17-1014-B416-88728C01EDA4  NaN

# %%
# we should fix some of these
registrations_df.at['7EE3500E-6E18-1014-9400-B664922230AB', 'control_number'] = 'A ad int. 27152'
registrations_df.at['7F934843-6E18-1014-9400-B664922230AB', 'control_number'] = 'A ad int. 27265'
registrations_df.at['7D944988-6E18-1014-9400-B664922230AB', 'control_number'] = 'A ad int. 27006'
registrations_df.at['7F2608C3-6E18-1014-9400-B664922230AB', 'control_number'] = 'A ad int. 27179'
registrations_df.at['7F3396D2-6E18-1014-9400-B664922230AB', 'control_number'] = 'A ad int. 27185'
registrations_df.at['7F0C9288-6E18-1014-9400-B664922230AB', 'control_number'] = 'A ad int. 27191'
registrations_df.at['7D90C472-6E18-1014-9400-B664922230AB', 'control_number'] = 'A ad int. 27027'
registrations_df.at['9B0B664D-6D0F-1014-9803-8BC52073E431', 'control_number'] = 'A404569'
registrations_df.at['74C5BB13-6E97-1014-9357-E9A0C844EAF1', 'control_number'] = 'A223224'
registrations_df.at['65934EB9-6E24-1014-A696-AD35B3FDE14F', 'control_number'] = 'A3347'
registrations_df.at['D0F4FB38-6D0A-1014-853A-B63123D40E62', 'control_number'] = 'A17092'
registrations_df.at['F589B7BA-6D13-1014-B63C-9736EB68D6D5', 'control_number'] = 'A602007'
registrations_df.at['05E3281B-6D14-1014-B63C-9736EB68D6D5', 'control_number'] = 'A601644'

# %%
# most registration number seem to hover around 7 characters, let's see if this is standard
len(registrations_df[registrations_df['control_number'].str.len() > 7])
# Out:
# 18120

# %%
# huh. well, let's look at some of these
registrations_df[registrations_df['control_number'].str.len() > 7].head(5)
# Out:
#                                                                          control_number  \
# id
# 85D6B068-767F-1014-AA44-F9F4E24D38B2                                    A765572 A765573
# 85E17D36-767F-1014-AA44-F9F4E24D38B2            A765638 A765639 A765640 A765954 A765955
# 86CA40D2-767F-1014-AA44-F9F4E24D38B2  A765986 A765987 A765988 A765989 A765990 A76599...
# 86E0E4ED-767F-1014-AA44-F9F4E24D38B2  A777076 A777077 A777078 A777079 A777080 A77708...
# 876E3661-767F-1014-AA44-F9F4E24D38B2                                    A777015 A777016
#
#                                      xml_year author  \
# id
# 85D6B068-767F-1014-AA44-F9F4E24D38B2     1924   None
# 85E17D36-767F-1014-AA44-F9F4E24D38B2     1924   None
# 86CA40D2-767F-1014-AA44-F9F4E24D38B2     1924   None
# 86E0E4ED-767F-1014-AA44-F9F4E24D38B2     1924   None
# 876E3661-767F-1014-AA44-F9F4E24D38B2     1924    NaN
#
#                                                                                   title  \
# id
# 85D6B068-767F-1014-AA44-F9F4E24D38B2                              Physiology and health
# 85E17D36-767F-1014-AA44-F9F4E24D38B2               Principles and practice of telephony
# 86CA40D2-767F-1014-AA44-F9F4E24D38B2                                   Arkansas reports
# 86E0E4ED-767F-1014-AA44-F9F4E24D38B2  Texas and Southwestern reporter digest, includ...
# 876E3661-767F-1014-AA44-F9F4E24D38B2                        Library of railway practice
#
#                                       edition publisher  \
# id
# 85D6B068-767F-1014-AA44-F9F4E24D38B2      NaN      None
# 85E17D36-767F-1014-AA44-F9F4E24D38B2  1st ed.      None
# 86CA40D2-767F-1014-AA44-F9F4E24D38B2      NaN      None
# 86E0E4ED-767F-1014-AA44-F9F4E24D38B2      NaN      None
# 876E3661-767F-1014-AA44-F9F4E24D38B2      NaN      None
#
#                                                                      desc  \
# id
# 85D6B068-767F-1014-AA44-F9F4E24D38B2                     2 v. illus. 19ͨͫ
# 85E17D36-767F-1014-AA44-F9F4E24D38B2           5 v. illus., diagrs. 19½ͨͫ
# 86CA40D2-767F-1014-AA44-F9F4E24D38B2                          13 v. 23½ͨͫ
# 86E0E4ED-767F-1014-AA44-F9F4E24D38B2                            2 v. 26ͨͫ
# 876E3661-767F-1014-AA44-F9F4E24D38B2  2 v. fronts., illus., diagrs. 21½ͨͫ
#
#                                      control_date        regDate copies  \
# id
# 85D6B068-767F-1014-AA44-F9F4E24D38B2   1924-01-02   Jan. 2, 1924    2c.
# 85E17D36-767F-1014-AA44-F9F4E24D38B2   1923-12-29  Dec. 29, 1923    2c.
# 86CA40D2-767F-1014-AA44-F9F4E24D38B2   1923-11-19        Nov. 19    2c.
# 86E0E4ED-767F-1014-AA44-F9F4E24D38B2   1923-11-15        Nov. 15    2c.
# 876E3661-767F-1014-AA44-F9F4E24D38B2   1924-01-15  Jan. 15, 1924    2c.
#
#                                            copyDate       affDate  \
# id
# 85D6B068-767F-1014-AA44-F9F4E24D38B2            NaN        Jan. 3
# 85E17D36-767F-1014-AA44-F9F4E24D38B2            NaN  Feb. 7, 1924
# 86CA40D2-767F-1014-AA44-F9F4E24D38B2  Feb. 11, 1924        Feb. 7
# 86E0E4ED-767F-1014-AA44-F9F4E24D38B2  Feb. 11, 1924        Feb. 7
# 876E3661-767F-1014-AA44-F9F4E24D38B2        Jan. 26        Feb. 8
#
#                                                                regNum  \
# id
# 85D6B068-767F-1014-AA44-F9F4E24D38B2                 A 765572, 765573
# 85E17D36-767F-1014-AA44-F9F4E24D38B2  A 765638-765640, 765954, 765955
# 86CA40D2-767F-1014-AA44-F9F4E24D38B2                  A 765986-765998
# 86E0E4ED-767F-1014-AA44-F9F4E24D38B2                  A 777076-777091
# 876E3661-767F-1014-AA44-F9F4E24D38B2                 A 777015, 777016
#
#                                          lccn  \
# id
# 85D6B068-767F-1014-AA44-F9F4E24D38B2  24-1323
# 85E17D36-767F-1014-AA44-F9F4E24D38B2  24-1728
# 86CA40D2-767F-1014-AA44-F9F4E24D38B2      NaN
# 86E0E4ED-767F-1014-AA44-F9F4E24D38B2      NaN
# 876E3661-767F-1014-AA44-F9F4E24D38B2  24-4029
#
#                                                                                    note  \
# id
# 85D6B068-767F-1014-AA44-F9F4E24D38B2                                                NaN
# 85E17D36-767F-1014-AA44-F9F4E24D38B2  CONTENTS.—[v. 1] Principles and apparatus.—[v....
# 86CA40D2-767F-1014-AA44-F9F4E24D38B2    cases determined … January, 1921, to July, 1923
# 86E0E4ED-767F-1014-AA44-F9F4E24D38B2  CONTENTS.—v. 2. Appeal and error*-Assignment o...
# 876E3661-767F-1014-AA44-F9F4E24D38B2  a general reference work on locomotive science...
#
#                                                                newMatterClaimed  \
# id
# 85D6B068-767F-1014-AA44-F9F4E24D38B2                  additional subject matter
# 85E17D36-767F-1014-AA44-F9F4E24D38B2                                        NaN
# 86CA40D2-767F-1014-AA44-F9F4E24D38B2                                        NaN
# 86E0E4ED-767F-1014-AA44-F9F4E24D38B2                                        NaN
# 876E3661-767F-1014-AA44-F9F4E24D38B2  introductory chapters by Hugh K. Christie
#
#                                                                 series  \
# id
# 85D6B068-767F-1014-AA44-F9F4E24D38B2  His Physiology and health series
# 85E17D36-767F-1014-AA44-F9F4E24D38B2                               NaN
# 86CA40D2-767F-1014-AA44-F9F4E24D38B2                               NaN
# 86E0E4ED-767F-1014-AA44-F9F4E24D38B2                               NaN
# 876E3661-767F-1014-AA44-F9F4E24D38B2                               NaN
#
#                                          vol volumes claimant prevPub  \
# id
# 85D6B068-767F-1014-AA44-F9F4E24D38B2     NaN     NaN      NaN     NaN
# 85E17D36-767F-1014-AA44-F9F4E24D38B2    v. 5     NaN      NaN     NaN
# 86CA40D2-767F-1014-AA44-F9F4E24D38B2  v. 159     NaN      NaN     NaN
# 86E0E4ED-767F-1014-AA44-F9F4E24D38B2    v. 3     NaN      NaN     NaN
# 876E3661-767F-1014-AA44-F9F4E24D38B2     NaN     NaN      NaN     NaN
#
#                                      additionalEntry prev-regNum noticeDate  \
# id
# 85D6B068-767F-1014-AA44-F9F4E24D38B2             NaN         NaN        NaN
# 85E17D36-767F-1014-AA44-F9F4E24D38B2             NaN         NaN        NaN
# 86CA40D2-767F-1014-AA44-F9F4E24D38B2             NaN         NaN        NaN
# 86E0E4ED-767F-1014-AA44-F9F4E24D38B2             NaN         NaN        NaN
# 876E3661-767F-1014-AA44-F9F4E24D38B2             NaN         NaN        NaN
#
#                                      role
# id
# 85D6B068-767F-1014-AA44-F9F4E24D38B2  NaN
# 85E17D36-767F-1014-AA44-F9F4E24D38B2  NaN
# 86CA40D2-767F-1014-AA44-F9F4E24D38B2  NaN
# 86E0E4ED-767F-1014-AA44-F9F4E24D38B2  NaN
# 876E3661-767F-1014-AA44-F9F4E24D38B2  NaN

# %%
# crap crap crap
registrations_df['control_number'].str.contains(' ').sum()
# Out:
# 4414

# %%
len(registrations_df[registrations_df['control_number'].str.len() > 15])
# Out:
# 1751

# %%
len(registrations_df[registrations_df['control_number'].str.len() > 100])
# Out:
# 84

# %%
len(registrations_df[registrations_df['control_number'].str.len() > 350])
# Out:
# 3

# %%
registrations_df[registrations_df['control_number'].str.len() > 350]
# Out:
#                                                                          control_number  \
# id
# 1A57A4C0-7289-1014-A093-F050B7410E2
# 'A144 A16 A17 A18 A19 A20 A21 A22 A23 A24 A25 A26 A27 A28 A29 A30 A31 A32 A33 A34 A35 A36 A37 A38 A39 A40 A41 A42 A43 A44 A45 A46 A47 A48 A49 A50 A51 A52 A53 A54 A55 A56 A57 A58 A59 A60 A61 A62 A63 A64 A65 A66 A67 A68 A69 A70 A71 A72 A73 A74 A75 A76 A77 A78 A79 A80 A81 A82 A83 A84 A85 A86 A87 A88 A89 A90 A91 A92 A93 A94 A95 A96 A97 A98 A99 A100 A101 A102 A103 A104 A105 A106 A107 A108 A109 A110 A111 A112 A113 A114 A115 A116 A117 A118 A119 A120 A121 A122 A123 A124 A125 A126 A127 A128 A129 A130 A131 A132 A133 A134 A135 A136 A137 A138 A139 A140 A141 A142 A143 A015'

# %%
registrations_df.at['1A57A4C0-7289-1014-A093-F050B7410E2F', 'regNum']
# Out:
# 'A144-015'

# %%
# lots of other entries are reg number ranges, but this one seems like it COULD
# be the result of a keystroke error -- an errant hyphen, since its neighbors are
# near the same number ranges and 7 characters -- A148626 & A154653, for example

# %%
# so let's see if there are any others like this
len(registrations_df[(registrations_df['control_number'].str.contains('-')) & (registrations_df['control_number'].str.len() == 7)])
# Out:
# 121

# %%
registrations_df[(registrations_df['control_number'].str.contains('-')) & (registrations_df['control_number'].str.len() == 7)].head()
# Out:
#                                      control_number xml_year author  \
# id
# 1C0C0AC6-6E16-1014-BA0A-C4B2DFF7CF27        A-19989     1930   None
# 4AE21A8A-6CF9-1014-A6CF-A82867D68027        A0-7713     1933   None
# BBD61233-6C64-1014-8713-889FF4349C01        A0-9905     1934   None
# C81A4EFA-6C64-1014-8713-889FF4349C01        A7-1008     1934   None
# 9621DAC3-6D82-1014-B070-FDFD250A9EDA        A8-7772     1935   None
#
#                                                                                   title  \
# id
# 1C0C0AC6-6E16-1014-BA0A-C4B2DFF7CF27  My friend the black bass: with strategy, mecha...
# 4AE21A8A-6CF9-1014-A6CF-A82867D68027                  Rizal and regaining our Eden lost
# BBD61233-6C64-1014-8713-889FF4349C01                                      The claimants
# C81A4EFA-6C64-1014-8713-889FF4349C01  The golden precepts from the book of life, emb...
# 9621DAC3-6D82-1014-B070-FDFD250A9EDA                   The Oakmont papers on immunology
#
#                                      edition publisher  \
# id
# 1C0C0AC6-6E16-1014-BA0A-C4B2DFF7CF27     NaN      None
# 4AE21A8A-6CF9-1014-A6CF-A82867D68027     NaN      None
# BBD61233-6C64-1014-8713-889FF4349C01     NaN      None
# C81A4EFA-6C64-1014-8713-889FF4349C01     NaN      None
# 9621DAC3-6D82-1014-B070-FDFD250A9EDA     NaN      None
#
#                                                                             desc  \
# id
# 1C0C0AC6-6E16-1014-BA0A-C4B2DFF7CF27  xiii p., 1 l., 288 p. front. (port.) 20ͨͫ.
# 4AE21A8A-6CF9-1014-A6CF-A82867D68027           xi, 111, [1] p. incl. port. 20½Cm
# BBD61233-6C64-1014-8713-889FF4349C01                       4 p. l., 283 p. 19½ͨͫ
# C81A4EFA-6C64-1014-8713-889FF4349C01                                 298 p. 24ͨͫ
# 9621DAC3-6D82-1014-B070-FDFD250A9EDA                  60 p. illus., diagrs. 23ͨͫ
#
#                                      control_date         regDate copies  \
# id
# 1C0C0AC6-6E16-1014-BA0A-C4B2DFF7CF27   1930-03-06    Mar. 6. 1930    2c.
# 4AE21A8A-6CF9-1014-A6CF-A82867D68027   1933-12-22   Dec. 22. 1933    2c.
# BBD61233-6C64-1014-8713-889FF4349C01   1934-03-14   Mar. 14, 1934    2c.
# C81A4EFA-6C64-1014-8713-889FF4349C01   1934-09-14  Sept. 14, 1934    2c.
# 9621DAC3-6D82-1014-B070-FDFD250A9EDA   1935-10-11   Oct. 11, 1935    2c.
#
#                                      copyDate   affDate    regNum      lccn  \
# id
# 1C0C0AC6-6E16-1014-BA0A-C4B2DFF7CF27      NaN       Mar   A-19989   30-7626
# 4AE21A8A-6CF9-1014-A6CF-A82867D68027      NaN   Dec. 27  A 0-7713    34-245
# BBD61233-6C64-1014-8713-889FF4349C01      NaN   Mar. 22  A 0-9905   34-5825
# C81A4EFA-6C64-1014-8713-889FF4349C01      NaN  Sept. 24  A 7-1008  34-40127
# 9621DAC3-6D82-1014-B070-FDFD250A9EDA  Oct. 16   Oct. 18  A 8-7772  35-30092
#
#                                                                                    note  \
# id
# 1C0C0AC6-6E16-1014-BA0A-C4B2DFF7CF27                                with a frontispiece
# 4AE21A8A-6CF9-1014-A6CF-A82867D68027                                                NaN
# BBD61233-6C64-1014-8713-889FF4349C01                                                NaN
# C81A4EFA-6C64-1014-8713-889FF4349C01                                                NaN
# 9621DAC3-6D82-1014-B070-FDFD250A9EDA  Papers on edwenil therapy by various authors, ...
#
#                                      newMatterClaimed series  vol volumes  \
# id
# 1C0C0AC6-6E16-1014-BA0A-C4B2DFF7CF27              NaN    NaN  NaN     NaN
# 4AE21A8A-6CF9-1014-A6CF-A82867D68027              NaN    NaN  NaN     NaN
# BBD61233-6C64-1014-8713-889FF4349C01              NaN    NaN  NaN     NaN
# C81A4EFA-6C64-1014-8713-889FF4349C01              NaN    NaN  NaN     NaN
# 9621DAC3-6D82-1014-B070-FDFD250A9EDA              NaN    NaN  NaN     NaN
#
#                                      claimant prevPub additionalEntry  \
# id
# 1C0C0AC6-6E16-1014-BA0A-C4B2DFF7CF27      NaN     NaN             NaN
# 4AE21A8A-6CF9-1014-A6CF-A82867D68027      NaN     NaN             NaN
# BBD61233-6C64-1014-8713-889FF4349C01      NaN     NaN             NaN
# C81A4EFA-6C64-1014-8713-889FF4349C01      NaN     NaN             NaN
# 9621DAC3-6D82-1014-B070-FDFD250A9EDA      NaN     NaN             NaN
#
#                                      prev-regNum noticeDate role
# id
# 1C0C0AC6-6E16-1014-BA0A-C4B2DFF7CF27         NaN        NaN  NaN
# 4AE21A8A-6CF9-1014-A6CF-A82867D68027         NaN        NaN  NaN
# BBD61233-6C64-1014-8713-889FF4349C01         NaN        NaN  NaN
# C81A4EFA-6C64-1014-8713-889FF4349C01         NaN        NaN  NaN
# 9621DAC3-6D82-1014-B070-FDFD250A9EDA         NaN        NaN  NaN

# %%
# these could certainly be errors. What about other len's?
len(registrations_df[(registrations_df['control_number'].str.contains('-')) & (registrations_df['control_number'].str.len() == 8)])
# Out:
# 2624

# %%
registrations_df[(registrations_df['control_number'].str.contains('-')) & (registrations_df['control_number'].str.len() == 8)].head()
# Out:
#                                      control_number xml_year author  \
# id
# 7FB36A48-6E18-1014-9400-B664922230AB       A-169025     1942   None
# 00456B1E-7455-1014-8580-A6F8A5D8C9B4       A-182896     1944   None
# E2B93611-6E15-1014-9EF1-AF99805A40AD       AP0-6735     1952   None
# 8B0EDFE8-6F17-1014-9F0D-96810182DD4A       B5-24695     1953   None
# 8BC38DA8-6F17-1014-9F0D-96810182DD4A       B5-24571     1953   None
#
#                                                                         title  \
# id
# 7FB36A48-6E18-1014-9400-B664922230AB                         Used-to-be days.
# 00456B1E-7455-1014-8580-A6F8A5D8C9B4                              Devious way
# E2B93611-6E15-1014-9EF1-AF99805A40AD  L'abbé Constantin. Illus. de E. Dufour.
# 8B0EDFE8-6F17-1014-9F0D-96810182DD4A            THE ADVENTURES OF HAP HAZARD.
# 8BC38DA8-6F17-1014-9F0D-96810182DD4A               McCarthy and anti-Semitism
#
#                                      edition publisher    desc control_date  \
# id
# 7FB36A48-6E18-1014-9400-B664922230AB     NaN       NaN     NaN   1942-11-16
# 00456B1E-7455-1014-8580-A6F8A5D8C9B4     NaN       NaN     NaN   1944-09-15
# E2B93611-6E15-1014-9EF1-AF99805A40AD     NaN      None  192 p.   1951-10-18
# 8B0EDFE8-6F17-1014-9F0D-96810182DD4A     NaN      None     NaN   1953-07-13
# 8BC38DA8-6F17-1014-9F0D-96810182DD4A     NaN      None     NaN   1953-06-23
#
#                                              regDate copies copyDate affDate  \
# id
# 7FB36A48-6E18-1014-9400-B664922230AB   Nov. 16, 1942    NaN      NaN     NaN
# 00456B1E-7455-1014-8580-A6F8A5D8C9B4  Sept. 15, 1944    NaN      NaN     NaN
# E2B93611-6E15-1014-9EF1-AF99805A40AD         18Oct51    NaN      NaN     NaN
# 8B0EDFE8-6F17-1014-9F0D-96810182DD4A           13Jul    NaN      NaN     NaN
# 8BC38DA8-6F17-1014-9F0D-96810182DD4A         23Jun53    NaN      NaN     NaN
#
#                                          regNum lccn                note  \
# id
# 7FB36A48-6E18-1014-9400-B664922230AB   A-169025  NaN                 NaN
# 00456B1E-7455-1014-8580-A6F8A5D8C9B4  A -182896  NaN                 NaN
# E2B93611-6E15-1014-9EF1-AF99805A40AD   AP0-6735  NaN                 NaN
# 8B0EDFE8-6F17-1014-9F0D-96810182DD4A   B5-24695  NaN  In the Co-operator
# 8BC38DA8-6F17-1014-9F0D-96810182DD4A   B5-24571  NaN           [Article]
#
#                                      newMatterClaimed                series  \
# id
# 7FB36A48-6E18-1014-9400-B664922230AB              NaN                   NaN
# 00456B1E-7455-1014-8580-A6F8A5D8C9B4              NaN                   NaN
# E2B93611-6E15-1014-9EF1-AF99805A40AD         on illus  (Bibliothèque verte)
# 8B0EDFE8-6F17-1014-9F0D-96810182DD4A              NaN                   NaN
# 8BC38DA8-6F17-1014-9F0D-96810182DD4A              NaN                   NaN
#
#                                       vol volumes claimant prevPub  \
# id
# 7FB36A48-6E18-1014-9400-B664922230AB  NaN     NaN      NaN     NaN
# 00456B1E-7455-1014-8580-A6F8A5D8C9B4  NaN     NaN      NaN     NaN
# E2B93611-6E15-1014-9EF1-AF99805A40AD  NaN     NaN      NaN     NaN
# 8B0EDFE8-6F17-1014-9F0D-96810182DD4A  NaN     NaN      NaN     NaN
# 8BC38DA8-6F17-1014-9F0D-96810182DD4A  NaN     NaN      NaN     NaN
#
#                                      additionalEntry prev-regNum noticeDate  \
# id
# 7FB36A48-6E18-1014-9400-B664922230AB             NaN         NaN        NaN
# 00456B1E-7455-1014-8580-A6F8A5D8C9B4             NaN         NaN        NaN
# E2B93611-6E15-1014-9EF1-AF99805A40AD             NaN         NaN        NaN
# 8B0EDFE8-6F17-1014-9F0D-96810182DD4A            None         NaN        NaN
# 8BC38DA8-6F17-1014-9F0D-96810182DD4A             NaN         NaN        NaN
#
#                                      role
# id
# 7FB36A48-6E18-1014-9400-B664922230AB  NaN
# 00456B1E-7455-1014-8580-A6F8A5D8C9B4  NaN
# E2B93611-6E15-1014-9EF1-AF99805A40AD  NaN
# 8B0EDFE8-6F17-1014-9F0D-96810182DD4A  NaN
# 8BC38DA8-6F17-1014-9F0D-96810182DD4A  NaN

# %%
registrations_df[(registrations_df['control_number'] == 'A4-79813') | (registrations_df['control_number'] == 'A479813') | (registrations_df['regNum'] == 'A479813')
                 | (registrations_df['regNum'] == 'A479813')]
# Out:
#                                      control_number xml_year author  \
# id
# 535E4CAA-6D03-1014-999C-964E71FFACD8        A479813     1961   None
# 869C6A67-6D03-1014-999C-964E71FFACD8       A4-79813     1961   None
#
#                                                                                title  \
# id
# 535E4CAA-6D03-1014-999C-964E71FFACD8                     Helping youth look at Jobs.
# 869C6A67-6D03-1014-999C-964E71FFACD8  A collection of papers of the rational theory.
#
#                                      edition publisher desc control_date  \
# id
# 535E4CAA-6D03-1014-999C-964E71FFACD8     NaN      None  NaN   1960-08-31
# 869C6A67-6D03-1014-999C-964E71FFACD8     NaN      None  NaN   1960-12-28
#
#                                       regDate copies copyDate affDate  \
# id
# 535E4CAA-6D03-1014-999C-964E71FFACD8  31Aug60    NaN      NaN     NaN
# 869C6A67-6D03-1014-999C-964E71FFACD8  28Dec60    NaN      NaN     NaN
#
#                                         regNum lccn  \
# id
# 535E4CAA-6D03-1014-999C-964E71FFACD8   A479813  NaN
# 869C6A67-6D03-1014-999C-964E71FFACD8  A4-79813  NaN
#
#                                                                note  \
# id
# 535E4CAA-6D03-1014-999C-964E71FFACD8  (SRA special guidance report)
# 869C6A67-6D03-1014-999C-964E71FFACD8                         Book 4
#
#                                      newMatterClaimed series  vol volumes  \
# id
# 535E4CAA-6D03-1014-999C-964E71FFACD8              NaN    NaN  NaN     NaN
# 869C6A67-6D03-1014-999C-964E71FFACD8              NaN    NaN  NaN     NaN
#
#                                      claimant prevPub additionalEntry  \
# id
# 535E4CAA-6D03-1014-999C-964E71FFACD8      NaN     NaN             NaN
# 869C6A67-6D03-1014-999C-964E71FFACD8      NaN     NaN            None
#
#                                      prev-regNum noticeDate role
# id
# 535E4CAA-6D03-1014-999C-964E71FFACD8         NaN        NaN  NaN
# 869C6A67-6D03-1014-999C-964E71FFACD8         NaN        NaN  NaN

# %%
registrations_df[(registrations_df['control_number'] == 'A144-015') | (registrations_df['control_number'] == 'A144015') |
                 (registrations_df['regNum'] == 'A144-015') | (registrations_df['regNum'] == 'A144015')]
# Out:
#                                                                          control_number  \
# id
# 07FB1489-70BF-1014-A0AD-E8B617DE6850                                            A144015
# 1A57A4C0-7289-1014-A093-F050B7410E2F  A144 A16 A17 A18 A19 A20 A21 A22 A23 A24 A25 A...
#
#                                      xml_year author  \
# id
# 07FB1489-70BF-1014-A0AD-E8B617DE6850     1940   None
# 1A57A4C0-7289-1014-A093-F050B7410E2F     1954   None
#
#                                                                                   title  \
# id
# 07FB1489-70BF-1014-A0AD-E8B617DE6850                        Poems, acrostics and songs.
# 1A57A4C0-7289-1014-A093-F050B7410E2F  Some notes on autoclave curing for Portland ce...
#
#                                      edition publisher  desc control_date  \
# id
# 07FB1489-70BF-1014-A0AD-E8B617DE6850     NaN      None   NaN   1939-12-07
# 1A57A4C0-7289-1014-A093-F050B7410E2F     NaN      None  5 l.   1954-05-20
#
#                                            regDate copies copyDate affDate  \
# id
# 07FB1489-70BF-1014-A0AD-E8B617DE6850  Dec. 7, 1939    NaN      NaN     NaN
# 1A57A4C0-7289-1014-A093-F050B7410E2F       20May54    NaN      NaN     NaN
#
#                                         regNum lccn note newMatterClaimed  \
# id
# 07FB1489-70BF-1014-A0AD-E8B617DE6850  A 144015  NaN  NaN              NaN
# 1A57A4C0-7289-1014-A093-F050B7410E2F  A144-015  NaN  NaN              NaN
#
#                                      series  vol volumes claimant prevPub  \
# id
# 07FB1489-70BF-1014-A0AD-E8B617DE6850    NaN  NaN     NaN      NaN     NaN
# 1A57A4C0-7289-1014-A093-F050B7410E2F    NaN  NaN     NaN      NaN     NaN
#
#                                      additionalEntry prev-regNum noticeDate  \
# id
# 07FB1489-70BF-1014-A0AD-E8B617DE6850             NaN         NaN        NaN
# 1A57A4C0-7289-1014-A093-F050B7410E2F             NaN         NaN        NaN
#
#                                      role
# id
# 07FB1489-70BF-1014-A0AD-E8B617DE6850  NaN
# 1A57A4C0-7289-1014-A093-F050B7410E2F  NaN

# %%
# at this point, it seems like that one was a processing error -- there are definitely ranges in the
# regNum field, but some registration numbers were robably improperly treated as ranges
# (has hypen, 7 or 8 characters)

# %%
# let's isolate these large-len entries and figure out if there are any more processing errors
temp = registrations_df[registrations_df['control_number'].str.len() > 200]
temp_2 = ((temp.reset_index(drop=False))[['id', 'control_number']]).to_dict('records')

# %%
# let's calculate the average size of each concatenated control number field
for entry in temp_2:
    numbers = entry['control_number'].split(' ')
    entry['avg'] = (sum(map(len, numbers)) / len(numbers))

# %%
temp_3 = [{'id': entry['id'], 'len': entry['avg']} for entry in temp_2 if entry['avg'] < 6]
pd.DataFrame(temp_3)
# Out:
#                                      id       len
# 0  1A57A4C0-7289-1014-A093-F050B7410E2F  3.353846

# %%
# that worked well. let's try it with a larger sample
temp = registrations_df[registrations_df['control_number'].str.len() > 50]
temp_2 = ((temp.reset_index(drop=False))[['id', 'control_number']]).to_dict('records')

for entry in temp_2:
    numbers = entry['control_number'].split(' ')
    entry['avg'] = (sum(map(len, numbers)) / len(numbers))
    
temp_3 = [{'id': entry['id'], 'len': entry['avg']} for entry in temp_2 if entry['avg'] < 6]
pd.DataFrame(temp_3)
# Out:
#                                      id       len
# 0  2A870394-6CB2-1014-A20E-B9D6251C946A  5.000000
# 1  86E5FBEF-6CFA-1014-9C3C-CEA95E7AA542  5.000000
# 2  875DD8C7-6CFA-1014-9C3C-CEA95E7AA542  5.000000
# 3  8BAA7768-6CFA-1014-9C3C-CEA95E7AA542  5.000000
# 4  92CBDE00-6CFA-1014-9C3C-CEA95E7AA542  5.000000
# 5  936EA631-6CFA-1014-9C3C-CEA95E7AA542  5.000000
# 6  597724E9-6E24-1014-A696-AD35B3FDE14F  4.000000
# 7  1A57A4C0-7289-1014-A093-F050B7410E2F  3.353846

# %%
# at the moment, the original one that stuck out looks like an anomaly. the others
# appear to be actual ranges of registration numbers, almost all of them in sequence, too

registrations_df.loc[['597724E9-6E24-1014-A696-AD35B3FDE14F', '936EA631-6CFA-1014-9C3C-CEA95E7AA542',
                      '8BAA7768-6CFA-1014-9C3C-CEA95E7AA542']]
# Out:
#                                                                          control_number  \
# id
# 597724E9-6E24-1014-A696-AD35B3FDE14F  A422 A423 A424 A425 A426 A427 A428 A429 A430 A...
# 936EA631-6CFA-1014-9C3C-CEA95E7AA542  A6213 A6214 A6215 A6216 A6217 A6218 A6219 A622...
# 8BAA7768-6CFA-1014-9C3C-CEA95E7AA542  A4275 A4276 A4277 A4278 A4279 A4280 A4281 A428...
#
#                                      xml_year author  \
# id
# 597724E9-6E24-1014-A696-AD35B3FDE14F     1946   None
# 936EA631-6CFA-1014-9C3C-CEA95E7AA542     1929   None
# 8BAA7768-6CFA-1014-9C3C-CEA95E7AA542     1929   None
#
#                                                                                   title  \
# id
# 597724E9-6E24-1014-A696-AD35B3FDE14F                        American law and procedure.
# 936EA631-6CFA-1014-9C3C-CEA95E7AA542  Required poetry for reading and memorizing in ...
# 8BAA7768-6CFA-1014-9C3C-CEA95E7AA542  Literature for reading and memorization for el...
#
#                                      edition publisher               desc  \
# id
# 597724E9-6E24-1014-A696-AD35B3FDE14F     NaN      None          23 1/2ͨͫ.
# 936EA631-6CFA-1014-9C3C-CEA95E7AA542     NaN      None  6 v. in 12. 19½ͨͫ
# 8BAA7768-6CFA-1014-9C3C-CEA95E7AA542     NaN      None         12 v. 19ͨͫ
#
#                                      control_date        regDate copies  \
# id
# 597724E9-6E24-1014-A696-AD35B3FDE14F   1946-01-05         5Jan46    NaN
# 936EA631-6CFA-1014-9C3C-CEA95E7AA542   1928-04-27  Apr. 27, 1928    2c.
# 8BAA7768-6CFA-1014-9C3C-CEA95E7AA542   1929-01-17  Jan. 17, 1929    1c.
#
#                                            copyDate  affDate  \
# id
# 597724E9-6E24-1014-A696-AD35B3FDE14F            NaN      NaN
# 936EA631-6CFA-1014-9C3C-CEA95E7AA542  Mar. 27, 1929  Mar. 28
# 8BAA7768-6CFA-1014-9C3C-CEA95E7AA542         Feb. 6   Feb. 4
#
#                                                  regNum      lccn  \
# id
# 597724E9-6E24-1014-A696-AD35B3FDE14F          A422-A434       NaN
# 936EA631-6CFA-1014-9C3C-CEA95E7AA542        A 6213-6224  28-31126
# 8BAA7768-6CFA-1014-9C3C-CEA95E7AA542  A 4275-4285, 5266   29-4659
#
#                                                                                    note  \
# id
# 597724E9-6E24-1014-A696-AD35B3FDE14F  Andrews and v. 12–14 revised by the publisher'...
# 936EA631-6CFA-1014-9C3C-CEA95E7AA542                                      [grade 1A-6B]
# 8BAA7768-6CFA-1014-9C3C-CEA95E7AA542                                grades 1A-6A, 2B-6B
#
#                                      newMatterClaimed series          vol  \
# id
# 597724E9-6E24-1014-A696-AD35B3FDE14F  Pub., revisions    NaN  Vols. 13–14
# 936EA631-6CFA-1014-9C3C-CEA95E7AA542              NaN    NaN          NaN
# 8BAA7768-6CFA-1014-9C3C-CEA95E7AA542              NaN    NaN          NaN
#
#                                      volumes claimant prevPub additionalEntry  \
# id
# 597724E9-6E24-1014-A696-AD35B3FDE14F    13 v      NaN     NaN             NaN
# 936EA631-6CFA-1014-9C3C-CEA95E7AA542     NaN      NaN     NaN             NaN
# 8BAA7768-6CFA-1014-9C3C-CEA95E7AA542     NaN      NaN     NaN             NaN
#
#                                      prev-regNum noticeDate role
# id
# 597724E9-6E24-1014-A696-AD35B3FDE14F         NaN        NaN  NaN
# 936EA631-6CFA-1014-9C3C-CEA95E7AA542         NaN        NaN  NaN
# 8BAA7768-6CFA-1014-9C3C-CEA95E7AA542         NaN        NaN  NaN

# %%
# so now we need to do 2 things: (1) replace the [control_number] field at id '1A57A4C0-7289-1014-A093-F050B7410E2F' with ['regNum']
registrations_df.at['1A57A4C0-7289-1014-A093-F050B7410E2F', 'control_number'] = registrations_df.at['1A57A4C0-7289-1014-A093-F050B7410E2F', 'regNum']
registrations_df.at['1A57A4C0-7289-1014-A093-F050B7410E2F', 'control_number']
# Out:
# 'A144-015'

# %%
# and (2) explode all the other [control_number] values that are separated by spaces
# current len of registrations_df:
len(registrations_df)
# Out:
# 580261

# %%
registrations_df['control_number'] = registrations_df['control_number'].str.split()

# %%
for index, row in tqdm(registrations_df.iterrows()):
    if len(row['control_number']) == 1:
        registrations_df.at[index, 'control_number'] = row['control_number'][0]
    else:
        pass
# Out:
# 580261it [01:05, 8907.99it/s]

# %%
registrations_df = registrations_df.explode('control_number')
len(registrations_df)
# Out:
# 590344

# %%
# now let's check for any more registration numbers that need to be cleaned up and exploded again... looking for
# string lengths of 8 characters or more seems like a good check, considering that most reg IDs are 6-7 characters
len(registrations_df[registrations_df['control_number'].str.len() > 8])
# Out:
# 58

# %%
registrations_df[registrations_df['control_number'].str.len() > 8]
# Out:
#                                        control_number xml_year author  \
# id
# 1717D971-6E16-1014-BA0A-C4B2DFF7CF27       A.-Foreign     1930   None
# 1737A33C-7289-1014-A093-F050B7410E2F       A157445125     1954    NaN
# 173E85E5-7289-1014-A093-F050B7410E2F     A14568112729     1954   None
# 17A1CDDA-72C4-1014-B53A-E905A29103D3
# 8E2A6FC1-6D0F-1014-9803-8BC52073E431                                    NaN
# 8EF67D10-7240-1014-AB88-AD98078397AF                                    NaN
# 93BB2D13-6D0F-1014-9803-8BC52073E431                                    NaN
# 940A806A-7673-1014-ACAA-B8C4DA013B26                                    NaN
# 954F585A-76FE-1014-8A60-894D8A9620E2                                    NaN
# 9558D741-6D0F-1014-9803-8BC52073E431                                    NaN
# 96E03DA6-6D0F-1014-9803-8BC52073E431                                    NaN
# 981BAB61-6C6D-1014-965B-8464748AEC84                                    NaN
# 98C5E42A-7240-1014-AB88-AD98078397AF                                    NaN
# A0C6B8B2-6F17-1014-9F0D-96810182DD4A                                    NaN
# A466AB22-6E3A-1014-83DD-942C093A1DD9                              9 v. 24ͨͫ
# A5A227D9-6E3A-1014-83DD-942C093A1DD9  3 v. illus. (incl. ports., map) 18½ͨͫ
# A8CA9F41-7240-1014-AB88-AD98078397AF                                    NaN
# C3407513-6C64-1014-8713-889FF4349C01             2 V. illus., diagrs. 19em.
# C70EE45D-6C64-1014-8713-889FF4349C01                             2 V. 27½ͨͫ
# C805EB6F-6C64-1014-8713-889FF4349C01                             2 v. 22½ͨͫ
# C8619317-6C64-1014-8713-889FF4349C01         2 v. front, (v. 2, port.) 21ͨͫ
# CA92E87A-728D-1014-92CC-D4C993EBA1C2                                    NaN
# D0082603-728D-1014-92CC-D4C993EBA1C2                                    NaN
# D4DC8406-6D0A-1014-853A-B63123D40E62          3 p. l., 217 p. illus. 21 ͨͫ.
# D54B9BA0-728D-1014-8500-D70EB891A161                                    NaN
# D903C665-728D-1014-8500-D70EB891A161                                1395 p.
# D9052D39-728D-1014-8500-D70EB891A161                                    NaN
# D90A77FA-728D-1014-8500-D70EB891A161                                    NaN
# D90DCB43-728D-1014-8500-D70EB891A161                                 145 p.
# D91A436A-728D-1014-8500-D70EB891A161                                1313 l.
# D9248B2F-728D-1014-8500-D70EB891A161                                    NaN
# D93187C8-728D-1014-8500-D70EB891A161                                    NaN
# D9337652-728D-1014-8500-D70EB891A161                                    NaN
# D935AB73-728D-1014-8500-D70EB891A161                                    NaN
# DCDF2753-6D0A-1014-853A-B63123D40E62                           illus. 22ͨͫ.
# E5DB6551-728D-1014-92CC-D4C993EBA1C2                                    NaN
# E64299B6-6E15-1014-9EF1-AF99805A40AD                                  24 p.
# EE2B1DB4-7454-1014-B915-B2A8CD83C03B                                    NaN
# EEE0E824-7288-1014-A093-F050B7410E2F                                    NaN
# F1B589E2-728D-1014-92CC-D4C993EBA1C2                                    NaN
#
#                                      control_date         regDate    copies  \
# id
# 1717D971-6E16-1014-BA0A-C4B2DFF7CF27   1928-11-01    Nov. 1, 1928       1c.
# 1737A33C-7289-1014-A093-F050B7410E2F   1954-10-01          1Oct54       NaN
# 173E85E5-7289-1014-A093-F050B7410E2F   1954-06-07            7Jun       NaN
# 17A1CDDA-72C4-1014-B53A-E905A29103D3   1957-02-08     5Feb-8Feb57       NaN
# 18E246F3-7289-1014-A093-F050B7410E2F   1954-10-15         15Oct54       NaN
# 1A590743-6E16-1014-BA0A-C4B2DFF7CF27   1930-01-27   Jan. 27, 1930       2c.
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27   1930-02-01    Feb. 1, 1930       2c.
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27   1930-02-01    Feb. 1, 1930       2c.
# 2262BB0C-715D-1014-A920-B56FE7FF3E29   1926-12-31   Dec. 31, 1926       2c.
# 2671BE8B-72C4-1014-84F6-87703AD4166D   1958-06-18         18Jun58       NaN
# 271E1344-6F26-1014-8881-C801964016F5   1958-10-08          8Oct58       NaN
# 2F8C2AEA-715D-1014-A920-B56FE7FF3E29   1927-07-29   July 29, 1927       2c.
# 3803A0D2-72C4-1014-84F6-87703AD4166D   1958-07-01          1Jul58       NaN
# 4131C5B9-75F5-1014-96EA-B4CA74C85597   1960-05-20         20May60       NaN
# 443D8C3D-798E-1014-9761-D3A611ADD299          NaN             NaN       NaN
# 4CC78743-6D06-1014-A65A-D57CF5CB45BA   1945-09-19  Sept. 19, 1945       NaN
# 5DB08207-6CFA-1014-B19C-B29A16CE9672   1958-11-05          5Nov58       NaN
# 5ED0BD3A-6D95-1014-B434-EB8C4702B141   1956-01-02          2Jan56       NaN
# 76B937E3-6D85-1014-9798-FBF77664F35B   1956-07-13         13Jul56       NaN
# 829DA8B8-6D85-1014-9798-FBF77664F35B   1956-06-25         25Jun56       NaN
# 87E05123-6D95-1014-B434-EB8C4702B141   1956-01-04          4Jan56       NaN
# 8B3A93D2-6D85-1014-9798-FBF77664F35B   1956-07-01          1Jul56       NaN
# 8E2A6FC1-6D0F-1014-9803-8BC52073E431   1959-10-09          9Oct59       NaN
# 8EF67D10-7240-1014-AB88-AD98078397A
# 98C5E42A-7240-1014-AB88-AD98078397AF  NaN
# A0C6B8B2-6F17-1014-9F0D-96810182DD4A  NaN
# A466AB22-6E3A-1014-83DD-942C093A1DD9  NaN
# A5A227D9-6E3A-1014-83DD-942C093A1DD9  NaN
# A8CA9F41-7240-1014-AB88-AD98078397AF  NaN
# C3407513-6C64-1014-8713-889FF4349C01  NaN
# C70EE45D-6C64-1014-8713-889FF4349C01  NaN
# C805EB6F-6C64-1014-8713-889FF4349C01  NaN
# C8619317-6C64-1014-8713-889FF4349C01  NaN
# CA92E87A-728D-1014-92CC-D4C993EBA1C2  NaN
# D0082603-728D-1014-92CC-D4C993EBA1C2  NaN
# D4DC8406-6D0A-1014-853A-B63123D40E62  NaN
# D54B9BA0-728D-1014-8500-D70EB891A161  NaN
# D903C665-728D-1014-8500-D70EB891A161  NaN
# D9052D39-728D-1014-8500-D70EB891A161  NaN
# D90A77FA-728D-1014-8500-D70EB891A161  NaN
# D90DCB43-728D-1014-8500-D70EB891A161  NaN
# D91A436A-728D-1014-8500-D70EB891A161  NaN
# D9248B2F-728D-1014-8500-D70EB891A161  NaN
# D93187C8-728D-1014-8500-D70EB891A161  NaN
# D9337652-728D-1014-8500-D70EB891A161  NaN
# D935AB73-728D-1014-8500-D70EB891A161  NaN
# DCDF2753-6D0A-1014-853A-B63123D40E62  NaN
# E5DB6551-728D-1014-92CC-D4C993EBA1C2  NaN
# E64299B6-6E15-1014-9EF1-AF99805A40AD  NaN
# EE2B1DB4-7454-1014-B915-B2A8CD83C03B  NaN
# EEE0E824-7288-1014-A093-F050B7410E2F  NaN
# F1B589E2-728D-1014-92CC-D4C993EBA1C2  NaN

# %%
# but there's also another problem: some registration IDs have been duplicated when they were processed by NYPL,
# or because they were included multiple times in the registration documents:
registrations_df.loc[['1D54896F-6E16-1014-BA0A-C4B2DFF7CF27']]
# Out:
#                                      control_number xml_year author  \
# id
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27  A20521-A20535     1930   None
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27   A21090-21114     1930   None
#
#                                                                                   title  \
# id
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27  Abbott New York digest … Consolidated ed. 1929...
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27  Abbott New York digest … Consolidated ed. 1929...
#
#                                      edition publisher        desc  \
# id
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27     NaN      None  40 v. 25".
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27     NaN      None  40 v. 25".
#
#                                      control_date       regDate copies  \
# id
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27   1930-02-01  Feb. 1, 1930    2c.
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27   1930-02-01  Feb. 1, 1930    2c.
#
#                                      copyDate  affDate  \
# id
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27      NaN  Mar. 14
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27      NaN  Mar. 14
#
#                                                           regNum lccn  \
# id
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27  A 20521-20535, 21090-21114  NaN
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27  A 20521-20535, 21090-21114  NaN
#
#                                                                                    note  \
# id
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27  These pamphlets are to be fitted into the back...
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27  These pamphlets are to be fitted into the back...
#
#                                      newMatterClaimed series  vol volumes  \
# id
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27              NaN    NaN  NaN     NaN
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27              NaN    NaN  NaN     NaN
#
#                                      claimant prevPub additionalEntry  \
# id
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27      NaN     NaN             NaN
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27      NaN     NaN             NaN
#
#                                      prev-regNum noticeDate role
# id
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27         NaN        NaN  NaN
# 1D54896F-6E16-1014-BA0A-C4B2DFF7CF27         NaN        NaN  NaN

# %%
# so we should fix the remaining registration numbers that need to be cleaned up, then explode the, 
# and finally de-dupe everything

# first, these should be fixed
registrations_df.at['1717D971-6E16-1014-BA0A-C4B2DFF7CF27', 'control_number'] = 'AF4644'
registrations_df.at['1737A33C-7289-1014-A093-F050B7410E2F', 'control_number'] = 'A157445'
registrations_df.at['173E85E5-7289-1014-A093-F050B7410E2F', 'control_number'] = 'A145681'
registrations_df.at['17A1CDDA-72C4-1014-B53A-E905A29103D3', 'control_number'] = 'BB3866 BB3867 BB3868 BB3869'
registrations_df.at['1A590743-6E16-1014-BA0A-C4B2DFF7CF27', 'control_number'] = 'A19206 A19298'
registrations_df.at['1D54896F-6E16-1014-BA0A-C4B2DFF7CF27', 'control_number'] = ('A20521 A20522 A20523 A20524 A20525 A20526 A20527 A20528 '
                                                                                 'A20529 A20530 A20531 A20532 A20533 A20534 A20535 A21090 '
                                                                                 'A21091 A21092 A21093 A21094 A21095 A21096 A21097 A21098 '
                                                                                 'A21099 A21100 A21101 A21102 A21103 A21104 A21105 A21106 '
                                                                                 'A21107 A21108 A21109 A21110 A21111 A21112 A21113 A21114')
registrations_df.at['2262BB0C-715D-1014-A920-B56FE7FF3E29', 'control_number'] = 'A958825 A958826 A958827 A958828 A958829 A958830 A958831 958832 A957862'
registrations_df.at['2671BE8B-72C4-1014-84F6-87703AD4166D', 'control_number'] = 'A346204 A353521'
registrations_df.at['271E1344-6F26-1014-8881-C801964016F5', 'control_number'] = 'A370932 A370933'
registrations_df.at['2F8C2AEA-715D-1014-A920-B56FE7FF3E29', 'control_number'] = 'A990443 A990444 A990445 A990446 A990447 A990448 A990449 A990450 A990451 A990452 A990453 A990454'
registrations_df.at['443D8C3D-798E-1014-9761-D3A611ADD299', 'control_number'] = 'A37589'
registrations_df.at['4CC78743-6D06-1014-A65A-D57CF5CB45BA', 'control_number'] = 'A1902-18'
registrations_df.at['5DB08207-6CFA-1014-B19C-B29A16CE9672', 'control_number'] = 'A505579 A505580'
registrations_df.at['5ED0BD3A-6D95-1014-B434-EB8C4702B141', 'control_number'] = 'A219700 A219701 A219702 A219703'
registrations_df.at['93BB2D13-6D0F-1014-9803-8BC52073E431', 'control_number'] = 'A414569 A414570 A414571 A414572'
registrations_df.at['940A806A-7673-1014-ACAA-B8C4DA013B26', 'control_number'] = 'A119580 A119581'
registrations_df.at['954F585A-76FE-1014-8A60-894D8A9620E2', 'control_number'] = 'A119514 A119515'
registrations_df.at['9558D741-6D0F-1014-9803-8BC52073E431', 'control_number'] = 'A28245'
registrations_df.at['96E03DA6-6D0F-1014-9803-8BC52073E431', 'control_number'] = 'A420869 A420870 A420871 A420872 A420873 A420874 A420875 A420876 A420877 A420878 A420879 A420880'
registrations_df.at['A466AB22-6E3A-1014-83DD-942C093A1DD9', 'control_number'] = 'A96935 A98447 A98810'
registrations_df.at['A5A227D9-6E3A-1014-83DD-942C093A1DD9', 'control_number'] = 'A100305 A100506 A100206'
registrations_df.at['C3407513-6C64-1014-8713-889FF4349C01', 'control_number'] = 'A69994 A70857'
registrations_df.at['C70EE45D-6C64-1014-8713-889FF4349C01', 'control_number'] = 'A74158 A73554'
registrations_df.at['C805EB6F-6C64-1014-8713-889FF4349C01', 'control_number'] = 'A78527 A78528'
registrations_df.at['C8619317-6C64-1014-8713-889FF4349C01', 'control_number'] = 'A77656 A77657'
registrations_df.at['D4DC8406-6D0A-1014-853A-B63123D40E62', 'control_number'] = 'A12598'
registrations_df.at['DCDF2753-6D0A-1014-853A-B63123D40E62', 'control_number'] = 'A18876 A13877'
registrations_df.at['E5DB6551-728D-1014-92CC-D4C993EBA1C2', 'control_number'] = 'B5-32309 B5-32350'
registrations_df.at['EEE0E824-7288-1014-A093-F050B7410E2F', 'control_number'] = 'A147511 A147513'
len(registrations_df)
# Out:
# 590344

# %%
# next, explode them
registrations_df['control_number'] = registrations_df['control_number'].str.split()

for index, row in tqdm(registrations_df.iterrows()):
    if len(row['control_number']) == 1:
        registrations_df.at[index, 'control_number'] = row['control_number'][0]
    else:
        pass
# Out:
# 590344it [01:13, 8032.37it/s]

# %%
registrations_df = registrations_df.explode('control_number')
len(registrations_df)
# Out:
# 689408

# %%
# finally, dedupe
registrations_df.drop_duplicates(keep='first', inplace=True)
len(registrations_df)
# Out:
# 580307

# %%
# even though we de-duped, we still have some duplicate indexed IDs:
registrations_df.index.duplicated().sum()
# Out:
# 95

# %%
registrations_df[registrations_df.index.duplicated()][:3]
# Out:
#                                      control_number xml_year author  \
# id
# 17A1CDDA-72C4-1014-B53A-E905A29103D3         BB3867     1957   None
# 17A1CDDA-72C4-1014-B53A-E905A29103D3         BB3868     1957   None
# 17A1CDDA-72C4-1014-B53A-E905A29103D3         BB3869     1957   None
#
#                                                           title edition  \
# id
# 17A1CDDA-72C4-1014-B53A-E905A29103D3  The National Guard story.     NaN
# 17A1CDDA-72C4-1014-B53A-E905A29103D3  The National Guard story.     NaN
# 17A1CDDA-72C4-1014-B53A-E905A29103D3  The National Guard story.     NaN
#
#                                      publisher desc control_date      regDate  \
# id
# 17A1CDDA-72C4-1014-B53A-E905A29103D3      None  NaN   1957-02-08  5Feb-8Feb57
# 17A1CDDA-72C4-1014-B53A-E905A29103D3      None  NaN   1957-02-08  5Feb-8Feb57
# 17A1CDDA-72C4-1014-B53A-E905A29103D3      None  NaN   1957-02-08  5Feb-8Feb57
#
#                                      copies copyDate affDate       regNum  \
# id
# 17A1CDDA-72C4-1014-B53A-E905A29103D3    NaN      NaN     NaN  BB3866-3869
# 17A1CDDA-72C4-1014-B53A-E905A29103D3    NaN      NaN     NaN  BB3866-3869
# 17A1CDDA-72C4-1014-B53A-E905A29103D3    NaN      NaN     NaN  BB3866-3869
#
#                                      lccn  \
# id
# 17A1CDDA-72C4-1014-B53A-E905A29103D3  NaN
# 17A1CDDA-72C4-1014-B53A-E905A29103D3  NaN
# 17A1CDDA-72C4-1014-B53A-E905A29103D3  NaN
#
#                                                                                    note  \
# id
# 17A1CDDA-72C4-1014-B53A-E905A29103D3  In Los Angeles evening herald & express, Feb. ...
# 17A1CDDA-72C4-1014-B53A-E905A29103D3  In Los Angeles evening herald & express, Feb. ...
# 17A1CDDA-72C4-1014-B53A-E905A29103D3  In Los Angeles evening herald & express, Feb. ...
#
#                                       newMatterClaimed series  vol volumes  \
# id
# 17A1CDDA-72C4-1014-B53A-E905A29103D3  NM: compilation.    NaN  NaN     NaN
# 17A1CDDA-72C4-1014-B53A-E905A29103D3  NM: compilation.    NaN  NaN     NaN
# 17A1CDDA-72C4-1014-B53A-E905A29103D3  NM: compilation.    NaN  NaN     NaN
#
#                                      claimant prevPub additionalEntry  \
# id
# 17A1CDDA-72C4-1014-B53A-E905A29103D3      NaN     NaN             NaN
# 17A1CDDA-72C4-1014-B53A-E905A29103D3      NaN     NaN             NaN
# 17A1CDDA-72C4-1014-B53A-E905A29103D3      NaN     NaN             NaN
#
#                                      prev-regNum noticeDate role
# id
# 17A1CDDA-72C4-1014-B53A-E905A29103D3         NaN        NaN  NaN
# 17A1CDDA-72C4-1014-B53A-E905A29103D3         NaN        NaN  NaN
# 17A1CDDA-72C4-1014-B53A-E905A29103D3         NaN        NaN  NaN

# %%
# so we'll need new unique identifiers for each entity. let's use the uuid library
registrations_df.reset_index(drop=False, inplace=True)
registrations_df['uuid'] = registrations_df.apply(lambda x: uuid4().hex, axis=1)
registrations_df['uuid'].duplicated().sum()
# Out:
# 0

# %%
registrations_df.set_index('uuid', inplace=True)

# %%
# now let's remove registrations without a registration number
registrations_df_cnums = registrations_df[(registrations_df['control_number'].notnull()) & (registrations_df['control_number'] != 'ERROR')]
len(registrations_df_cnums)
# Out:
# 580162

# %%
# are any control dates empty?
len(registrations_df_cnums[registrations_df_cnums['control_date'].isnull()])
# Out:
# 1330

# %%
# well that's a problem. Additionally, are any of the control dates not in YYYY-MM-DD format?
(registrations_df_cnums.sort_values(by=['control_date'])).head(8)
# Out:
#                                                                     id  \
# uuid
# 89e64034fc5d4d6aadb4c5146b53cbf2  9271E7A0-6D17-1014-B416-88728C01EDA4
# 0fe0f49ed2044054ae9335c5789b1a16  9EF9D8F0-6D0F-1014-9803-8BC52073E431
# 617918245489497b8a00817d326c2dc1  C825EBA4-6D17-1014-B416-88728C01EDA4
# 2015b9f4c4124b0d94199ca94f8ffe51  F52190C1-6D13-1014-B63C-9736EB68D6D5
# 3b6de506eca6496a9530c7cd46341bef  9E9760C3-6D0F-1014-9803-8BC52073E431
# c841e5c8b8024a16b5f81be1344b14b0  C477BE74-6D13-1014-B63C-9736EB68D6D5
# 02e99574f9c340538ff5d5ff205da972  9E988846-6D0F-1014-9803-8BC52073E431
# 43ccfa3079704d768f20c0a2938e75ce  9EFE6BCF-6D0F-1014-9803-8BC52073E431
#
#                                  control_number xml_year author  \
# uuid
# 89e64034fc5d4d6aadb4c5146b53cbf2        A544246     1962    NaN
# 0fe0f49ed2044054ae9335c5789b1a16        A410549     1959   None
# 617918245489497b8a00817d326c2dc1        A563336     1962   None
# 2015b9f4c4124b0d94199ca94f8ffe51        A578167     1962   None
# 3b6de506eca6496a9530c7cd46341bef        A396269     1959   None
# c841e5c8b8024a16b5f81be1344b14b0        A587712     1962   None
# 02e99574f9c340538ff5d5ff205da972        A396272     1959   None
# 43ccfa3079704d768f20c0a2938e75ce        A402926     1959   None
#
#                                                                               title  \
# uuid
# 89e64034fc5d4d6aadb4c5146b53cbf2  ESSEX COUNTY (N. J.) REAL ESTATE DIRECTORY; re...
# 0fe0f49ed2044054ae9335c5789b1a16  Greener thumbs. July 6, 1959 through October 3...
# 617918245489497b8a00817d326c2dc1                              Telephone directories
# 2015b9f4c4124b0d94199ca94f8ffe51  The colonial image; origins of American cultur...
# 3b6de506eca6496a9530c7cd46341bef                                          Statutes.
# c841e5c8b8024a16b5f81be1344b14b0                         Electric eye movie manual.
# 02e99574f9c340538ff5d5ff205da972                                Cases and statutes.
# 43ccfa3079704d768f20c0a2938e75ce                 International Bible lesson column.
#
#                                  edition publisher desc control_date  regDate  \
# uuid
# 89e64034fc5d4d6aadb4c5146b53cbf2     NaN      None  NaN           01      Jan
# 0fe0f49ed2044054ae9335c5789b1a16     NaN      None  NaN         0159        3
# 617918245489497b8a00817d326c2dc1     NaN      None  NaN           03      Mar
# 2015b9f4c4124b0d94199ca94f8ffe51     NaN      None  NaN        04-02   2Aprb2
# 3b6de506eca6496a9530c7cd46341bef     NaN      None  NaN        04-28    28Apr
# c841e5c8b8024a16b5f81be1344b14b0     NaN      None  NaN        05-06  21May6l
# 02e99574f9c340538ff5d5ff205da972     NaN      None  NaN        05-07     7May
# 43ccfa3079704d768f20c0a2938e75ce     NaN      None  NaN        05-11    11May
#
#                                  copies copyDate affDate   regNum lccn  \
# uuid
# 89e64034fc5d4d6aadb4c5146b53cbf2    NaN      NaN     NaN  A544246  NaN
# 0fe0f49ed2044054ae9335c5789b1a16    NaN      NaN     NaN  A410549  NaN
# 617918245489497b8a00817d326c2dc1    NaN      NaN     NaN  A563336  NaN
# 2015b9f4c4124b0d94199ca94f8ffe51    NaN      NaN     NaN  A578167  NaN
# 3b6de506eca6496a9530c7cd46341bef    NaN      NaN     NaN  A396269  NaN
# c841e5c8b8024a16b5f81be1344b14b0    NaN      NaN     NaN  A587712  NaN
# 02e99574f9c340538ff5d5ff205da972    NaN      NaN     NaN  A396272  NaN
# 43ccfa3079704d768f20c0a2938e75ce    NaN      NaN     NaN  A402926  NaN
#
#                                                note  \
# uuid
# 89e64034fc5d4d6aadb4c5146b53cbf2                NaN
# 0fe0f49ed2044054ae9335c5789b1a16                NaN
# 617918245489497b8a00817d326c2dc1                NaN
# 2015b9f4c4124b0d94199ca94f8ffe51                NaN
# 3b6de506eca6496a9530c7cd46341bef                NaN
# c841e5c8b8024a16b5f81be1344b14b0                NaN
# 02e99574f9c340538ff5d5ff205da972                NaN
# 43ccfa3079704d768f20c0a2938e75ce  For 24May-28Jun59
#
#                                                        newMatterClaimed  \
# uuid
# 89e64034fc5d4d6aadb4c5146b53cbf2                                    NaN
# 0fe0f49ed2044054ae9335c5789b1a16                                    NaN
# 617918245489497b8a00817d326c2dc1                                    NaN
# 2015b9f4c4124b0d94199ca94f8ffe51  NM: pref., introd. & connecting notes
# 3b6de506eca6496a9530c7cd46341bef                                    NaN
# c841e5c8b8024a16b5f81be1344b14b0                                    NaN
# 02e99574f9c340538ff5d5ff205da972                                    NaN
# 43ccfa3079704d768f20c0a2938e75ce                                    NaN
#
#                                  series                 vol volumes claimant  \
# uuid
# 89e64034fc5d4d6aadb4c5146b53cbf2    NaN                 NaN     NaN      NaN
# 0fe0f49ed2044054ae9335c5789b1a16    NaN                 NaN     NaN      NaN
# 617918245489497b8a00817d326c2dc1    NaN                 NaN     NaN      NaN
# 2015b9f4c4124b0d94199ca94f8ffe51    NaN                 NaN     NaN      NaN
# 3b6de506eca6496a9530c7cd46341bef    NaN         v.40, no. 3     NaN      NaN
# c841e5c8b8024a16b5f81be1344b14b0    NaN                 NaN     NaN      NaN
# 02e99574f9c340538ff5d5ff205da972    NaN  v.53, no. 2, May59     NaN      NaN
# 43ccfa3079704d768f20c0a2938e75ce    NaN                 NaN     NaN      NaN
#
#                                  prevPub      additionalEntry prev-regNum  \
# uuid
# 89e64034fc5d4d6aadb4c5146b53cbf2     NaN                  1,          NaN
# 0fe0f49ed2044054ae9335c5789b1a16     NaN                  NaN         NaN
# 617918245489497b8a00817d326c2dc1     NaN                  NaN         NaN
# 2015b9f4c4124b0d94199ca94f8ffe51     NaN                  NaN         NaN
# 3b6de506eca6496a9530c7cd46341bef     NaN                  NaN         NaN
# c841e5c8b8024a16b5f81be1344b14b0     NaN                  NaN         NaN
# 02e99574f9c340538ff5d5ff205da972     NaN                  3,          NaN
# 43ccfa3079704d768f20c0a2938e75ce     NaN  20Dec59-24Jan60. ©          NaN
#
#                                  noticeDate role
# uuid
# 89e64034fc5d4d6aadb4c5146b53cbf2        NaN  NaN
# 0fe0f49ed2044054ae9335c5789b1a16        NaN  NaN
# 617918245489497b8a00817d326c2dc1        NaN  NaN
# 2015b9f4c4124b0d94199ca94f8ffe51        NaN  NaN
# 3b6de506eca6496a9530c7cd46341bef        NaN  NaN
# c841e5c8b8024a16b5f81be1344b14b0        NaN  NaN
# 02e99574f9c340538ff5d5ff205da972        NaN  NaN
# 43ccfa3079704d768f20c0a2938e75ce        NaN  NaN

# %%
# well that's kind of a problem too. let's set these to null, otherwise it'll mess up
# our matching attempts later on. We have the year of registration from the XML data,
# so we'll construct an identifier with the control number and the year of registration
# in a little bit

# %%
# loop through rows matching dates to a regex; if no match, set to NaN
for index, row in tqdm(registrations_df_cnums.iterrows()):
    if (pd.isnull(row['control_date'])):
        pass
    else:
        prog = re.compile(r"^\d{4}\-\d{2}\-\d{2}$")
        result = prog.match(str(row['control_date']))
        if result:
            pass
        else:
            registrations_df_cnums.at[index, 'control_date'] = np.NaN
# Out:
# 580162it [00:57, 10168.63it/s]

# %%
# now, how many control dates are empty?
len(registrations_df_cnums[registrations_df_cnums['control_date'].isnull()])
# Out:
# 1570

# %%
# we'll separate the ones without a reg date into their own DF
registrations_df_cnums_no_dates = registrations_df_cnums[registrations_df_cnums['control_date'].isnull()]
len(registrations_df_cnums_no_dates)
# Out:
# 1570

# %%
# and make a new DF for not-null control date records
registrations_df_cnums_dates = registrations_df_cnums[registrations_df_cnums['control_date'].notnull()]
len(registrations_df_cnums_dates)
# Out:
# 578592

# %%
# now let's create unique identifiers for the date/nodate DFs
# cdmid = cross-dimensional matching identifier (with control date)
registrations_df_cnums_dates['cdmid'] = registrations_df_cnums_dates.apply(lambda x: x['control_number'] + '|' + x['control_date'], axis=1)
# Out:
# /home/scottythered/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# cdmid_nd = cross-dimensional matching identifier (no control date)
registrations_df_cnums_no_dates['cdmid_nd'] = registrations_df_cnums_no_dates.apply(lambda x: x['control_number'] + '|' + x['xml_year'], axis=1)
# Out:
# /home/scottythered/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # To sum up:
#
# - **registrations_df** --> all registration records
# - **registrations_df_cnums** --> all registrations that have control numbers
# - **registrations_df_cnums_no_dates** --> all registrations with control numbers but no dates, just years (cdmid_nd)
# - **registrations_df_cnums_dates** --> all registrations with control numbers and dates (cdmid)

# %% [markdown]
# # 2. Copyright Renewals
#
# ## Again, some suppositions:
#
# 1. "Often more than one registration is involved, such as when a book is first published outside the United States and has an 'interim' registration (class AI) before it's final registration. \[...\] Renewal *R129296* refers to both the interim registration, *AI-9217*, and final registration, *A972756*. This illustrates the importance of the id numbers, since the two original registrations have two different titles and wouldn't be clear otherwise that they are the same book. This allows us to easily match the two registrations found in the Registrations data."
#
# 2. Again, copyright registrations that happened after 1963 were renewed automatically, so there's no point in matching for them.
#
# 3. Also, copyright registrations that happened *before* 1924 are currently in the public domain, so there's no point in matching those either.

# %%
# load up directory of copyright renewals coded as tab-separated docs
renewals_directory = os.path.join(base_path, 'cce-renewals-master', 'data')
renewals_files = [x for x in os.listdir(renewals_directory) if x[-4:] == '.tsv']
renewals_df = pd.DataFrame()
for file in tqdm(renewals_files):
    temp_df = pd.read_csv(os.path.join(renewals_directory, file), sep='\t', header=0)
    renewals_df = renewals_df.append(temp_df, sort=False, ignore_index=True)
# Out:
# 100%|██████████| 47/47 [00:12<00:00,  1.70it/s]

# %%
# some later TSVs have an incorrect version of the title header...
temp = (renewals_df[renewals_df['titl'].notnull()]).index.tolist()
temp[:5]
# Out:
# [175931, 175932, 175933, 175934, 175935]

# %%
# ...and the same TSVs have an incorrect version of author
temp_2 = (renewals_df[renewals_df['auth'].notnull()]).index.tolist()
temp_2[:5]
# Out:
# [175931, 175932, 175933, 175934, 175935]

# %%
# move these pieces of data to the correct columns...
for index, row in tqdm(renewals_df.iterrows()):
    if index >= 12960:
        renewals_df.at[index, 'title'] = row['titl']
        renewals_df.at[index, 'author'] = row['auth']
    else:
        pass
# Out:
# 445386it [00:51, 8716.62it/s]

# %%
# ...then drop the incorrect heading columns
renewals_df.drop(['titl', 'auth'], axis=1, inplace=True)

# %%
# Get indexes for rows where copyright registrations happened after 1963 or before 1924
temp = renewals_df[renewals_df['odat'].notnull()]
temp['year'] = temp.apply(lambda x: int((x['odat'].split('-'))[0]), axis=1)
indexes = temp[(temp['year'] < 1924) | (temp['year'] > 1963)].index
# Out:
# /home/scottythered/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
len(indexes)
# Out:
# 8154

# %%
len(renewals_df)
# Out:
# 445386

# %%
# Delete these roww from the dataFrame
renewals_df.drop(indexes, inplace=True)
len(renewals_df)
# Out:
# 437232

# %%
# now then, do we have duplicate entity ids?
renewals_df['entry_id'].duplicated().sum()
# Out:
# 13738

# %%
# sigh
renewals_df[renewals_df['entry_id'].duplicated()].sort_values('entry_id')[3:6]
# Out:
#                                    entry_id  volume part  number    page  \
# 18193  000dfedf-e0da-5c46-b700-b1bd0bd78f13     8.0    1     2.0  1531.0
# 18195  000dfedf-e0da-5c46-b700-b1bd0bd78f13     8.0    1     2.0  1531.0
# 18194  000dfedf-e0da-5c46-b700-b1bd0bd78f13     8.0    1     2.0  1531.0
#
#       author title     oreg        odat       id        rdat  \
# 18193    NaN   NaN  B754474  1927-10-06  R138115  1954-10-22
# 18195    NaN   NaN  B755955  1927-10-20  R138117  1954-10-22
# 18194    NaN   NaN  B754640  1927-10-13  R138116  1954-10-22
#
#                                           claimants new_matter see_also_ren  \
# 18193  Dorothy Benjamin Caruso & Torrance Goddard|A        NaN          NaN
# 18195  Dorothy Benjamin Caruso & Torrance Goddard|A        NaN          NaN
# 18194  Dorothy Benjamin Caruso & Torrance Goddard|A        NaN          NaN
#
#       see_also_reg notes                                          full_text  \
# 18193          NaN   NaN  CARUSO, DOROTHY BENJAMIN. Wings of song, by Do...
# 18195          NaN   NaN  CARUSO, DOROTHY BENJAMIN. Wings of song, by Do...
# 18194          NaN   NaN  CARUSO, DOROTHY BENJAMIN. Wings of song, by Do...
#
#       dreg note
# 18193  NaN  NaN
# 18195  NaN  NaN
# 18194  NaN  NaN

# %%
# okay, we'll need to take care of that by adding UUIDs
renewals_df['uuid'] = renewals_df.apply(lambda x: uuid4().hex, axis=1)
renewals_df['uuid'].duplicated().sum()
# Out:
# 0

# %%
# we'll also need to do a check for any multi-renewal numbers in the 'oreg' field
renewals_df['oreg'].str.contains(' ').sum()
# Out:
# 1345

# %%
# sigh
renewals_df[(renewals_df['oreg'].str.contains(' ')) & (renewals_df['oreg'].notnull())]
# Out:
#                                     entry_id  volume part  number  page  \
# 1536    200047e3-0519-5307-9ac6-98c156fd3588     4.0  14A     1.0  35.0
# 205880  aea39bc9-b4c6-153e-d432-b7b53e193c66     NaN  NaN     NaN   NaN
# 294954  45807b0f-2bc6-51ec-d96a-ccc1cad0588d     NaN  NaN     NaN   NaN
# 296052  3322d17b-efb8-9aa8-21d3-f13cfc33e036     NaN  NaN     NaN   NaN
# 297963  75919c10-ac72-9984-94fc-303386e76e62     NaN  NaN     NaN   NaN
# ...                                      ...     ...  ...     ...   ...
# 443530  c002fed3-97fa-f013-9b4b-a39cd5cb44bf     NaN  NaN     NaN   NaN
# 443531  2d438545-14c9-eeec-8998-1704f1ca1d2b     NaN  NaN     NaN   NaN
# 443532  6b43214a-d29b-0fc6-7500-1cb5274ecb07     NaN  NaN     NaN   NaN
# 444438  da3084b5-8597-d42d-3a13-238725b54fcc     NaN  NaN     NaN   NaN
# 445368  8af87ff3-1c0d-eac9-e5c2-cbe3884724ed     NaN  NaN     NaN   NaN
#
#                                                    author  \
# 1536                                                  NaN
# 205880                                                NaN
# 294954                                                NaN
# 296052                                                NaN
# 297963                                                NaN
# ...                                                   ...
# 443530                                      Harry Street.
# 443531                                                NaN
# 443532                                      Harry Street.
# 444438                                   Brian W. Aldiss.
# 445368  D. M. Matheson, employee for hire of George Al...
#
#                                                     title                oreg  \
# 1536                                  MAYFLOWER. (Butter)         Label 25885
# 205880  The Hills of Korea.  Words & music: Joseph C. ...  B00000000005 20688
# 294954  Rio Batucada.  English lyrics by John Wedgwood...            UCC work
# 296052  The Craft of fiction.  Foreword and editorial:...            UCC work
# 297963  Selected poems of William Blake.  Introd. and ...            UCC work
# ...                                                   ...                 ...
# 443530              Freedom, the individual, and the law.            UCC work
# 443531  The Pelican history of music.  Vol. 2: Renaiss...            UCC work
# 443532               Freedom, the individual and the law.            UCC work
# 444438                                     Skeleton crew.            UCC work
# 445368            Comprendre l'Islam|Understanding Islam.            UCC work
#
#               odat        id        rdat                      claimants  \
# 1536    1925-03-13    R60206  1950-03-29  Pickerington Creamery, Inc.|P
# 205880  1952-03-26   RE46245         NaN             Joseph C. Murphy|A
# 294954  1956-12-11  RE407262         NaN              Nezika Connelly|W
# 296052  1957-01-01  RE260995         NaN                    John Pym|NK
# 297963  1957-02-01  RE268736         NaN                F. W. Bateson|A
# ...            ...       ...         ...                            ...
# 443530  1963-11-28  RE571534         NaN             Muriel H. Street|W
# 443531  1963-11-28  RE557164         NaN        Penguin Books, Ltd.|PWH
# 443532  1963-11-28  RE557167         NaN                Robert Street|C
# 444438  1963-12-13  RE555779         NaN              Brian W. Aldiss|A
# 445368  1963-12-12  RE594125         NaN            Frithjof Schuon|PWH
#
#        new_matter see_also_ren see_also_reg notes  \
# 1536          NaN          NaN          NaN   NaN
# 205880        NaN          NaN          NaN   NaN
# 294954        NaN          NaN          NaN   NaN
# 296052        NaN          NaN          NaN   NaN
# 297963        NaN          NaN          NaN   NaN
# ...           ...          ...          ...   ...
# 443530        NaN          NaN          NaN   NaN
# 443531        NaN          NaN          NaN   NaN
# 443532        NaN          NaN          NaN   NaN
# 444438        NaN          NaN          NaN   NaN
# 445368        NaN          NaN          NaN   NaN
#
#                                                 full_text        dreg note  \
# 1536    MAYFLOWER. (Butter) © 13Mar25, Label 25885. R6...         NaN  NaN
# 205880                                                NaN  1980-01-08  NaN
# 294954                                                NaN  1984-12-20  NaN
# 296052                                                NaN  1985-10-04  NaN
# 297963                                                NaN  1985-12-23  NaN
# ...                                                   ...         ...  ...
# 443530                                                NaN  1991-12-23  NaN
# 443531                                                NaN  1991-12-12  NaN
# 443532                                                NaN  1991-12-12  NaN
# 444438                                                NaN  1991-12-16  NaN
# 445368                                                NaN  1992-12-04  NaN
#
#                                     uuid
# 1536    d46d065e70634a44a13f7ed7c63e98d9
# 205880  d90eb15f3efa4f6fbaa3765662498852
# 294954  1f0712498eb643d4842322af335b14fd
# 296052  5d699df5269045de88700901bbec3801
# 297963  a991db81d0424135bfb632a21ceda67d
# ...                                  ...
# 443530  84280382833843f688abd5acbee3b14c
# 443531  2f9eead2ea834d7296e37a6dbe807de6
# 443532  3b3a10e9d9064dd68ac31187a5114c61
# 444438  6062e7c4da284777a7ae48acf90ddcf8
# 445368  3e4f7f5a59624f5c81c67021ff3f06e7
#
# [1345 rows x 20 columns]

# %%
# lets fix that second one
renewals_df.at[205880, 'oreg'] = 'B520688'

# %%
# i don't know what 'UCC work' means. they're not useful, so let's set those to blank
blanked = (renewals_df[(renewals_df['oreg'].str.contains('UCC work')) & (renewals_df['oreg'].notnull())]).index.to_list()
len(blanked)
# Out:
# 1321

# %%
for index in tqdm(blanked):
    renewals_df.at[index, 'oreg'] = np.NaN
# Out:
# 100%|██████████| 1321/1321 [00:00<00:00, 46854.42it/s]

# %%
# check it again
renewals_df[(renewals_df['oreg'].str.contains(' ')) & (renewals_df['oreg'].notnull())]
# Out:
#                                     entry_id  volume part  number  page  \
# 1536    200047e3-0519-5307-9ac6-98c156fd3588     4.0  14A     1.0  35.0
# 335222  9f560931-8bd9-d974-2423-ed395061d365     NaN  NaN     NaN   NaN
# 413267  c5b73508-10bd-a863-33c8-36433abbcc6a     NaN  NaN     NaN   NaN
# 415596  c92f168d-8e7e-2436-5b49-30b085b788ad     NaN  NaN     NaN   NaN
# 418257  75d22f77-8676-1a1a-f668-0b897a48faec     NaN  NaN     NaN   NaN
# 421788  36a09665-46c5-d56a-b9ee-c5b058aee15c     NaN  NaN     NaN   NaN
# 423528  d6a1515a-56c2-ea60-40fe-74161dc500f3     NaN  NaN     NaN   NaN
# 424331  6d0e3366-a008-783a-7533-6f6c6a685049     NaN  NaN     NaN   NaN
# 429682  91d92297-9883-b931-c1bc-7d4a4caa2cb8     NaN  NaN     NaN   NaN
# 430070  185856a0-8a42-6ce2-4198-9f13a610594d     NaN  NaN     NaN   NaN
# 432373  1b75ce4c-4c5e-ece9-33ba-ca4bc7625607     NaN  NaN     NaN   NaN
# 432754  c7f5fab4-7e59-9765-d04b-5808e963cd63     NaN  NaN     NaN   NaN
# 434523  ada33b10-61ae-19e5-2a34-1679e52c3ef6     NaN  NaN     NaN   NaN
# 434878  708178b4-9002-a590-edec-4327b1ad6be8     NaN  NaN     NaN   NaN
# 434924  b5987651-b796-9e9b-d55f-2db28eb00209     NaN  NaN     NaN   NaN
# 434925  28d1aff5-a409-9a1b-7f56-cca472b820fd     NaN  NaN     NaN   NaN
# 434926  0d8f1027-c978-26ce-122b-a91dfb195365     NaN  NaN     NaN   NaN
# 436895  c3617196-86b4-a635-1200-6e22c361c2da     NaN  NaN     NaN   NaN
# 438551  74490dcf-c09e-1d5a-7e13-7722d03c2b4e     NaN  NaN     NaN   NaN
# 438813  3398a553-ac71-4357-6c02-fd28fdaf9fd1     NaN  NaN     NaN   NaN
# 439768  85e6c24d-bdb2-5648-82d2-336cacd0cc26     NaN  NaN     NaN   NaN
# 439769  a2f0302a-1277-92e4-361e-521f83b9622e     NaN  NaN     NaN   NaN
# 441199  dd6cb762-fde3-7ca8-4c01-341a3a48911e     NaN  NaN     NaN   NaN
#
#                                           author  \
# 1536                                         NaN
# 335222                              B. R. Nanda.
# 413267                                       NaN
# 415596  Henry Cecil, pseud. of Henry Cecil Leon.
# 418257                                       NaN
# 421788  Leo Bruce, pseud. of Rupert Croft-Cooke.
# 423528                                       NaN
# 424331                                       NaN
# 429682                                       NaN
# 430070                             Dick Sadleir.
# 432373                                       NaN
# 432754                                       NaN
# 434523                                       NaN
# 434878                                       NaN
# 434924                                       NaN
# 434925                                       NaN
# 434926                                       NaN
# 436895                                       NaN
# 438551                                       NaN
# 438813                                       NaN
# 439768                                       NaN
# 439769                                       NaN
# 441199                           Elizabeth Hely.
#
#                                                     title         oreg  \
# 1536                                  MAYFLOWER. (Butter)  Label 25885
# 335222                       Mahatma Gandhi; a biography.  U.C.C. work
# 413267  The Statesman's year-book: statistical and his...  U.C.C. work
# 415596                                Unlawful occasions.     USC work
# 418257                                         Inflation.  U.C.C. work
# 421788                                Nothing like blood.  UCC renewal
# 423528                      On the beat.  m Philip Green.  U.C.C. work
# 424331                         Panatella.  m Ron Goodwin.  U.C.C. work
# 429682  Bless your heart, my darling.  w & m Alex Alst...  U.C.C. work
# 430070                     Rhythm and blues guitar solos.  U.C.C. work
# 432373  Walkin' tall.  w & m Len Beadle, Robin Conrad ...  U.C.C. work
# 432754  That's all I need.  w Ian Burford, m Lance Mul...  U.C.C. work
# 434523  A Shorter history of Rome.  Text: M. Cary & Jo...     UCC Work
# 434878       Tickled pink.  m Frank Sherry, Fred Hartley.  U.C.C. work
# 434924  The Dream maker.  w Norman Newell, m Philip Gr...  U.C.C. work
# 434925                            Bush baby.  m Syd Dale.  U.C.C. work
# 434926        The Wild wind.  w Gil King, m Tony Osborne.  U.C.C. work
# 436895  Always the lonely one.  w Hazel Adair, Peter L...  U.C.C. work
# 438551                 Midsummer madness.  m Ron Goodwin.  U.C.C. work
# 438813                 Runaway lovers.  Text: Berta Ruck.     UCC Work
# 439768                 Song of summer.  w & m John Hynam.  U.C.C. work
# 439769  A Day without you.  w Norman Newell, m Philip ...  U.C.C. work
# 441199                                     The Long shot.  UCC renewal
#
#               odat        id        rdat  \
# 1536    1925-03-13    R60206  1950-03-29
# 335222  1958-12-01  RE344004         NaN
# 413267  1962-08-09  RE512474         NaN
# 415596  1962-09-17  RE487528         NaN
# 418257  1962-10-25  RE512475         NaN
# 421788  1962-12-30  RE512034         NaN
# 423528  1963-01-24  RE557645         NaN
# 424331  1963-02-07  RE557644         NaN
# 429682  1963-04-29  RE557653         NaN
# 430070  1963-05-03  RE557652         NaN
# 432373  1963-06-10  RE557640         NaN
# 432754  1963-06-17  RE557651         NaN
# 434523  1963-07-16  RE557193         NaN
# 434878  1963-07-23  RE557641         NaN
# 434924  1963-07-24  RE557647         NaN
# 434925  1963-07-24  RE557648         NaN
# 434926  1963-07-24  RE557642         NaN
# 436895  1963-08-27  RE557649         NaN
# 438551  1963-09-19  RE557646         NaN
# 438813  1963-09-23  RE557192         NaN
# 439768  1963-10-03  RE557643         NaN
# 439769  1963-10-03  RE557650         NaN
# 441199  1963-10-23  RE547948         NaN
#
#                                           claimants new_matter see_also_ren  \
# 1536                  Pickerington Creamery, Inc.|P        NaN          NaN
# 335222                                B. R. Nanda|A        NaN          NaN
# 413267  Macmillan Academic & Professional, Ltd.|PCW        NaN          NaN
# 415596                               Barbara Leon|W        NaN          NaN
# 418257       International Economic Association|PCW        NaN          NaN
# 421788                         Richard Hitchcock|NK        NaN          NaN
# 423528                         Dorothy Mary Green|W        NaN          NaN
# 424331                                Ron Goodwin|A        NaN          NaN
# 429682        Alex Alstone|A||Derek James Kennedy|C        NaN          NaN
# 430070                              L. H. Sadleir|W        NaN          NaN
# 432373                                          NaN        NaN          NaN
# 432754               Lance Mulcahy|A||Ian Burford|A        NaN          NaN
# 434523               A. M. G. Cary|C||John Wilson|A        NaN          NaN
# 434878                               Frank Sherry|A        NaN          NaN
# 434924        Norman Newell|A||Dorothy Mary Green|W        NaN          NaN
# 434925                                   Syd Dale|A        NaN          NaN
# 434926                   Tony Osborne|A||Gil King|A        NaN          NaN
# 436895                  Hazel Adair|A||Peter Ling|A        NaN          NaN
# 438551                                Ron Goodwin|A        NaN          NaN
# 438813                               W. R. Oliver|C        NaN          NaN
# 439768                                 John Hynam|A        NaN          NaN
# 439769        Norman Newell|A||Dorothy Mary Green|W        NaN          NaN
# 441199          Lavender Mary Jean Goddard-Wilson|E        NaN          NaN
#
#        see_also_reg notes                                          full_text  \
# 1536            NaN   NaN  MAYFLOWER. (Butter) © 13Mar25, Label 25885. R6...
# 335222          NaN   NaN                                                NaN
# 413267          NaN   NaN                                                NaN
# 415596          NaN   NaN                                                NaN
# 418257          NaN   NaN                                                NaN
# 421788          NaN   NaN                                                NaN
# 423528          NaN   NaN                                                NaN
# 424331          NaN   NaN                                                NaN
# 429682          NaN   NaN                                                NaN
# 430070          NaN   NaN                                                NaN
# 432373          NaN   NaN                                                NaN
# 432754          NaN   NaN                                                NaN
# 434523          NaN   NaN                                                NaN
# 434878          NaN   NaN                                                NaN
# 434924          NaN   NaN                                                NaN
# 434925          NaN   NaN                                                NaN
# 434926          NaN   NaN                                                NaN
# 436895          NaN   NaN                                                NaN
# 438551          NaN   NaN                                                NaN
# 438813          NaN   NaN                                                NaN
# 439768          NaN   NaN                                                NaN
# 439769          NaN   NaN                                                NaN
# 441199          NaN   NaN                                                NaN
#
#               dreg note                              uuid
# 1536           NaN  NaN  d46d065e70634a44a13f7ed7c63e98d9
# 335222  1986-11-03  NaN  c173154dac1d4e9cbfeb4c5c96ed36a7
# 413267  1990-12-31  NaN  8f03e3ca44124bb4823bc5550ef7d2ba
# 415596  1990-05-07  NaN  e0e8ce83e197436f88ac1ecb4de2455a
# 418257  1990-12-31  NaN  ce5fa8541d8d4882b3e351ed8be98b9c
# 421788  1990-12-17  NaN  7d9c6bd19acc418ab5814a49d4db2a51
# 423528  1991-12-24  NaN  c9eeab8f55ac4dfbb91b4caa9348e675
# 424331  1991-12-24  NaN  f566669a104749bba6f1631f4ea33c64
# 429682  1991-12-23  NaN  52b5ff0f628c4f32936e62f8dd157edb
# 430070  1991-12-23  NaN  4c1f1d8dc1ca4386852a18302c2e7543
# 432373  1991-12-24  NaN  8481563619b2486f8eada4385ab888d8
# 432754  1991-12-23  NaN  3069bf97a0104783961e6dcd2b1b9510
# 434523  1991-12-13  NaN  0ff0cd17453940deba7b1bac7a0204dc
# 434878  1991-12-24  NaN  0292272493874b3c9cc27fddc337c780
# 434924  1991-12-24  NaN  cc9a2980c2de4456866ec408f6ec6c40
# 434925  1991-12-24  NaN  587457a233da446e8724e4fba0644176
# 434926  1991-12-24  NaN  b4ded8b5f64f43b5843acbf467e8636c
# 436895  1991-12-24  NaN  03003b709483484fa62b071d3f78b1f1
# 438551  1991-12-24  NaN  c2eedfad8c9f4b9d839108338e0de20d
# 438813  1991-12-17  NaN  f124eb30871745c88f6e3a75b9a63cec
# 439768  1991-12-24  NaN  e70681b2f4ee4fb481a41f567f07a824
# 439769  1991-12-24  NaN  58d8a756ed7e4f4cad8e4c51af1784ea
# 441199  1991-10-09  NaN  c678e95bb3364485b9892c81a8b6eb5d

# %%
# finish it up with a second round
blanked_2 = (renewals_df[(renewals_df['oreg'].str.contains(' ')) & (renewals_df['oreg'].notnull())][1:]).index.to_list()
for index in tqdm(blanked_2):
    renewals_df.at[index, 'oreg'] = np.NaN
# Out:
# 100%|██████████| 22/22 [00:00<00:00, 50423.33it/s]

# %%
# next, any duplicates?
renewals_df.duplicated().sum()
# Out:
# 0

# %%
# now let's find all records missing oregs and remove them
len(renewals_df[renewals_df['oreg'].isnull()])
# Out:
# 3037

# %%
renewals_df_cnums = renewals_df[renewals_df['oreg'].notnull()]
len(renewals_df_cnums)
# Out:
# 434195

# %%
# any missing reg dates?
len(renewals_df_cnums[renewals_df_cnums['odat'].isnull()])
# Out:
# 21

# %%
renewals_df_cnums[renewals_df_cnums['odat'].isnull()]
# Out:
#                                     entry_id  volume part  number    page  \
# 71601   d329cd30-9842-5067-88fb-d5ef20b7e984    18.0    1     2.0  2224.0
# 113289  d10e51ac-acfa-532d-a823-78d9323e83df    24.0    1     1.0  1433.0
# 136373  8b69828f-e476-598c-8c6a-2c93a473fd04    27.0    1     1.0  1809.0
# 182658  076b1995-25ba-e997-1764-07a74ffe7cfd     NaN  NaN     NaN     NaN
# 339835             The Eskimo, arctic hunters & trappers.   A380916  NaN
# 351995                                       Stand on me.   AF18222  NaN
# 373575        Billboard.  Vol. 72, no. 44, Oct. 31, 1960.   B865577  NaN
# 373576                                The Song of Roland.  A4758597  NaN
# 380772      Massachusetts digest annotated.  Vol. 16-16A.   A496190  NaN
# 382319  Time; the weekly magazine (incorporating Liter...   B888416  NaN
# 425645        The Instructor.  Vol. 98, no. 2, Feb. 1963.    B18470  NaN
# 425646    The Commonweal.  Vol. 77, no. 24, Mar. 8, 1963.    B25150  NaN
# 425647  The Surgical clinics of North America.  Chicag...    B29688  NaN
#
#               id        rdat  \
# 71601    R346845  1964-10-19
# 113289   R476844  1970-01-16
# 136373   R544382  1973-01-19
# 182658   RE10320         NaN
# 189765   RE17937         NaN
# 190008   RE54289         NaN
# 252266  RE137594         NaN
# 279715  RE222859         NaN
# 309262  RE271598         NaN
# 311072  RE244854         NaN
# 319781  RE305686         NaN
# 319782  RE303500         NaN
# 339835  RE334283         NaN
# 351995  RE349339         NaN
# 373575  RE385213         NaN
# 373576  RE395638         NaN
# 380772  RE422079         NaN
# 382319  RE424538         NaN
# 425645  RE535106         NaN
# 425646  RE537632         NaN
# 425647  RE562305         NaN
#
#                                                 claimants new_matter  \
# 71601                                  Walter E. Disney|A        NaN
# 113289                                      Walt Coburn|A        NaN
# 136373                                   John W. Schaum|A        NaN
# 182658                    The Nation Associates, Inc.|PCW        NaN
# 189765                            Samuel French, Inc.|PWH        NaN
# 190008                                    Truman Capote|A        NaN
# 252266                        West Publishing Company|PWH        NaN
# 279715                           Academic Press, Inc.|PCW        NaN
# 309262                  Conde Nast Publications, Inc.|PWH        NaN
# 311072                  United States Naval Institute|PWH        NaN
# 319781           Southbrook Entertainment Corporation|PWH        NaN
# 319782               Western Publishing Company, Inc.|PWH        NaN
# 339835               Herbert S. Zim|A||Patricia Boodell|A        NaN
# 351995                                 Geraldine Norman|W        NaN
# 373575                   Billboard Publications, Inc.|PCW        NaN
# 373576            Eleanor Clark|A||Random House, Inc.|PWH        NaN
# 380772                        West Publishing Company|PWH        NaN
# 382319                                     Time, Inc.|PCW        NaN
# 425645  Corporation of the President of the Church of ...        NaN
# 425646                          Commonweal Foundation|PCW        NaN
# 425647                         W. B. Saunders Company|PCW        NaN
#
#        see_also_ren see_also_reg notes  \
# 71601           NaN          NaN   NaN
# 113289          NaN          NaN   NaN
# 136373          NaN          NaN   NaN
# 182658          NaN          NaN   NaN
# 189765          NaN          NaN   NaN
# 190008          NaN          NaN   NaN
# 252266          NaN          NaN   NaN
# 279715          NaN          NaN   NaN
# 309262          NaN          NaN   NaN
# 311072          NaN          NaN   NaN
# 319781          NaN          NaN   NaN
# 319782          NaN          NaN   NaN
# 339835          NaN          NaN   NaN
# 351995          NaN          NaN   NaN
# 373575          NaN          NaN   NaN
# 373576          NaN          NaN   NaN
# 380772          NaN          NaN   NaN
# 382319          NaN          NaN   NaN
# 425645          NaN          NaN   NaN
# 425646          NaN          NaN   NaN
# 425647          NaN          NaN   NaN
#
#                                                 full_text        dreg  \
# 71601   DISNEY, WALTER E. Donald Duck, by Walt Disney....         NaN
# 113289  COBURN, WALT. Dower rights to Gunsmoke Ranch. ...         NaN
# 136373  SCHAUM, JOHN W., comp. John W. Schaum note spe...         NaN
# 182658                                                NaN  1978-12-18
# 189765                                                NaN  1979-01-16
# 190008                                                NaN  1979-12-17
# 252266                                                NaN  1982-10-01
# 279715                                                NaN  1984-12-11
# 309262                                                NaN  1985-12-23
# 311072                                                NaN  1985-04-18
# 319781                                                NaN  1986-09-23
# 319782                                                NaN  1986-09-15
# 339835                                                NaN  1987-03-23
# 351995                                                NaN  1987-09-14
# 373575                                                NaN  1988-06-03
# 373576                                                NaN  1988-09-22
# 380772                                                NaN  1989-04-03
# 382319                                                NaN  1989-03-21
# 425645                                                NaN  1991-07-15
# 425646                                                NaN  1991-01-07
# 425647                                                NaN  1991-12-19
#
#                                                      note  \
# 71601                                                 NaN
# 113289                                                NaN
# 136373                                                NaN
# 182658                                                NaN
# 189765                                                NaN
# 190008  First chapter of under ti.: The Grass harp app...
# 252266                                                NaN
# 279715                                                NaN
# 309262                                                NaN
# 311072                                                NaN
# 319781                                                NaN
# 319782                                                NaN
# 339835                                                NaN
# 351995                                                NaN
# 373575                                                NaN
# 373576                                                NaN
# 380772                                                NaN
# 382319                                                NaN
# 425645                                                NaN
# 425646                                                NaN
# 425647                                                NaN
#
#                                     uuid
# 71601   061508f7a6044d8d8c0402756b369411
# 113289  f4b612128efd4ccbbe083370e7673ca8
# 136373  67c5890254ab43daa446f8e59b627d5e
# 182658  b2fe21ce47b248d3b57ec4621e9c5298
# 189765  25379ca5e0ad45349688df3baa61d399
# 190008  ef8c5a27b6a446faaba00e45312bf4b5
# 252266  8af32a36ccbe4e50801db27fe0fe6b2e
# 279715  dc97c0b8dc2a4edc9ed3a1b4aaaa6370
# 309262  4a27792c244343f0993af11d4b64bf9b
# 311072  ca2801def318417e8db28f36f98fae8f
# 319781  a375ffb1316d45ad85253a25a11f8b99
# 319782  e627d962c60c442cb61a76f3908bb4e2
# 339835  d6dbf59c0cc94d82b199902eb72bfae2
# 351995  6652aaa6847c4ab4a92a8354752c8d45
# 373575  0fa24abe55f346aaa576daff57dec83e
# 373576  a79716a934514810ae9a2ee1d608ccde
# 380772  0bdbe81368f642f09c7f5bc9eb9de81a
# 382319  d085149a502741ddb82026685bb9bbce
# 425645  9554f8eee7f64f108a11bc06d0d30ea9
# 425646  662215b000b9409f8d87a380526d8639
# 425647  81772bbc2f484177829d7c00482c994e

# %%
# remove them from the DF
renewals_df_cleaned = renewals_df_cnums[renewals_df_cnums['odat'].notnull()]

# %%
len(renewals_df_cleaned)
# Out:
# 434174

# %%
# quick check to make sure all odates are correctly formed
(renewals_df_cleaned.sort_values(by=['odat'])).head(5)
# Out:
#                                   entry_id  volume part  number   page  \
# 8843  09cff772-4d5c-5251-a3db-3ffca339d09c     5.0   1A     2.0  658.0
# 8119  1c8e5597-9ff8-50ee-807d-48731ce1feac     5.0   1A     2.0  641.0
# 8914  217d2d3e-c8f0-50c1-aa42-3ca6abfb0499     5.0   1A     2.0  659.0
# 7046  411694c9-6fc5-5a47-9f8f-7c8ff42d956e     5.0   1A     1.0  251.0
# 8913  3919bb25-1b99-536a-9337-f8019165c302     5.0   1A     2.0  659.0
#
#                 author                                              title  \
# 8843               NaN             SWARTWOOD, CHARLES C. My Mayday queen.
# 8119               NaN  FENTON, CARROLL LANE. The age of mammals. (Lit...
# 8914  Otto A. Horsack.  UNION SPECIAL MACHINE COMPANY. Samples of doub...
# 7046               NaN  GEISTER, EDNA. Breaking the ice in January. (T...
# 8913  Otto A. Horsack.  UNION SPECIAL MACHINE COMPANY. Samples of doub...
#
#          oreg        odat      id        rdat                      claimants  \
# 8843  A776398  1924-01-01  R86928  1951-12-03         Charles C. Swartwood|A
# 8119  A777274  1924-01-01  R87794  1951-12-29        Haldeman-Julius Co.|PWH
# 8914  A773769  1924-01-01  R83813  1951-09-28  Union Special Machine Co.|PWH
# 7046  A776238  1924-01-01  R75329  1951-02-26                 Edna Geister|A
# 8913  A773767  1924-01-01  R83811  1951-09-28  Union Special Machine Co.|PWH
#
#      new_matter see_also_ren see_also_reg notes  \
# 8843        NaN          NaN          NaN   NaN
# 8119        NaN          NaN          NaN   NaN
# 8914        NaN          NaN          NaN   NaN
# 7046        NaN          NaN          NaN   NaN
# 8913        NaN          NaN          NaN   NaN
#
#                                               full_text dreg note  \
# 8843  SWARTWOOD, CHARLES C. My Mayday queen. © 1Jan2...  NaN  NaN
# 8119  FENTON, CARROLL LANE. The age of mammals. (Lit...  NaN  NaN
# 8914  UNION SPECIAL MACHINE COMPANY. Samples of doub...  NaN  NaN
# 7046  GEISTER, EDNA. Breaking the ice in January. (T...  NaN  NaN
# 8913  UNION SPECIAL MACHINE COMPANY. Samples of doub...  NaN  NaN
#
#                                   uuid
# 8843  16a167bc41dd47758838deb961f2cffa
# 8119  37083e053c80406bbc3278e0d7221997
# 8914  2663049e844a4d2fa213468b35ac871b
# 7046  66c13ef9dd0f4615836b457163bb2600
# 8913  d07b840c21954509a750bd7cbe2a8e6b

# %%
renewals_df_cleaned.sort_values(by=['odat'], ascending=False).head(5)
# Out:
#                                     entry_id  volume part  number  page  \
# 445265  7e2bbfb3-fa32-65e3-f964-2775c9866bd5     NaN  NaN     NaN   NaN
# 445239  325dc00d-a05f-765d-beca-12c797f37e15     NaN  NaN     NaN   NaN
# 445259  6b8479b2-adb1-411c-c294-60f9c469ba1a     NaN  NaN     NaN   NaN
# 445258  0781bc78-04cf-3c03-14f7-e1bebcfbf3ca     NaN  NaN     NaN   NaN
# 445257  6f7d3e78-61dd-cb19-5915-7ff62f3a9dd7     NaN  NaN     NaN   NaN
#
#                                        author  \
# 445265  Harold W. Rusch and Frank Scimonelli.
# 445239     John Polgreen & Cathleen Polgreen.
# 445259                                    NaN
# 445258                         Richard Estes.
# 445257                                    NaN
#
#                                                     title     oreg  \
# 445265      Advanced band method|B-flat cornet & trumpet.  A700221
# 445239                               Our friend, the sun.  A682549
# 445259  Perspectives in medieval history.  Editors: Ka...  A698997
# 445258  Fossil vertebrates from the late Cretaceous La...  A696286
# 445257  Adventures in public service.  Editors: Delia ...  A691919
#
#               odat        id rdat                               claimants  \
# 445265  1963-12-31  RE538905  NaN  Hal Leonard Publishing Corporation|PWH
# 445239  1963-12-31  RE547382  NaN        Henry Holt and Company, Inc.|PWH
# 445259  1963-12-31  RE548363  NaN       William Marsh Rice University|PCW
# 445258  1963-12-31  RE565750  NaN                         Richard Estes|A
# 445257  1963-12-31  RE548352  NaN                            Delia Kuhn|A
#
#        new_matter see_also_ren see_also_reg notes full_text        dreg note  \
# 445265        NaN          NaN          NaN   NaN       NaN  1991-07-22  NaN
# 445239        NaN          NaN          NaN   NaN       NaN  1991-10-04  NaN
# 445259        NaN          NaN          NaN   NaN       NaN  1991-10-23  NaN
# 445258        NaN          NaN          NaN   NaN       NaN  1991-12-31  NaN
# 445257        NaN          NaN          NaN   NaN       NaN  1991-10-15  NaN
#
#                                     uuid
# 445265  61f13f6b01b84eb798098f7c7b82bd17
# 445239  17cd99458b584afabf26ec3047a0e6dc
# 445259  03c02270a5ea484fab04a7c8c4bfa86c
# 445258  e44a7f6414064b34a1ce68a4ec52ac6a
# 445257  3083a8c1793a46b6b2101364029e073a

# %%
# now let's create unique identifiers for the DFs
renewals_df_cleaned['cdmid'] = renewals_df.apply(lambda x: str(x['oreg']) + '|' + str(x['odat']), axis=1)
# Out:
# /home/scottythered/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
renewals_df_cleaned['cdmid_nd'] = renewals_df.apply(lambda x: str(x['oreg']) + '|' + (str(x['odat']).split('-')[0]), axis=1)
# Out:
# /home/scottythered/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
len(renewals_df_cleaned)
# Out:
# 434174

# %%
renewals_df_cleaned.head()
# Out:
#                                   entry_id  volume part  number  page  \
# 122   6efc89b0-7542-5e93-8207-69e1900bb0ef     4.0  14A     1.0   3.0
# 753   c3ef9a6f-8355-5961-9aeb-79715a323766     4.0  14A     1.0  18.0
# 1057  9f623d7a-1c30-5a31-be18-76e452743ef2     4.0  14A     1.0  25.0
# 1105  bdf4a5d8-3d80-54de-8c75-2601d08e0284     4.0  14A     1.0  26.0
# 1200  64ed4644-14c2-54ad-85da-8d0b218921c6     4.0  14A     1.0  27.0
#
#                 author                                              title  \
# 122       E. F. Benson  AT THE FARMHOUSE; later included in VISIBLE AN...
# 753   Richard Connell.  FISTS (In the Saturday evening post, Mar. 10, ...
# 1057      E. F. Benson  INSCRUTABLE DECREES; later included in VISIBLE...
# 1105               NaN  INSURANCE MAPS. Edinburgh, Christian County, I...
# 1200               NaN  IT'S NEVER TOO LATE, a comedy in three acts by...
#
#          oreg        odat      id        rdat  \
# 122   A778640  1924-03-28  R59144  1950-02-23
# 753   B571853  1925-03-08  R61904  1950-05-04
# 1057  A778640  1924-03-28  R59866  1950-03-16
# 1105   F42232  1925-04-10  R62490  1950-05-17
# 1200   D64453  1925-05-12  R63230  1950-06-08
#
#                                               claimants new_matter  \
# 122                 Kenneth Stewart Patrick McDowall|NK        NaN
# 753                                Louise Fox Connell|W        NaN
# 1057                Kenneth Stewart Patrick McDowall|NK        NaN
# 1105                                Sanborn Map Co.|PWH        NaN
# 1200  Elizabeth Glass Wardell|C||Jules Eckert Goodman|A        NaN
#
#      see_also_ren see_also_reg                         notes  \
# 122           NaN          NaN  pub. abroad 20Feb23, AI-4984
# 753           NaN          NaN                           NaN
# 1057          NaN          NaN  pub. abroad 14Mar23, AI-5023
# 1105          NaN          NaN                           NaN
# 1200          NaN          NaN                           NaN
#
#                                               full_text dreg note  \
# 122   AT THE FARMHOUSE, by E. F. Benson; later inclu...  NaN  NaN
# 753   FISTS, by Richard Connell. (In the Saturday ev...  NaN  NaN
# 1057  INSCRUTABLE DECREES, by E. F. Benson; later in...  NaN  NaN
# 1105  INSURANCE MAPS. © Sanborn Map Co. (PWH) Edinbu...  NaN  NaN
# 1200  IT'S NEVER TOO LATE, a comedy in three acts by...  NaN  NaN
#
#                                   uuid               cdmid      cdmid_nd
# 122   03609b71da864fcc9a6319e58782cb1c  A778640|1924-03-28  A778640|1924
# 753   2af515ad21af405a94b45534ca94163a  B571853|1925-03-08  B571853|1925
# 1057  ccc034a864fb40a68f099fafbbbddb96  A778640|1924-03-28  A778640|1924
# 1105  2e0b51f7c4174e4db9c847386e3a0433   F42232|1925-04-10   F42232|1925
# 1200  7f8d7aae0c504c41b27dc969a0cd4f2b   D64453|1925-05-12   D64453|1925

# %%
with shelve.open('shelf.p', 'c') as shelf:
    shelf['registrations_df'] = registrations_df
    shelf['registrations_df_cnums'] = registrations_df_cnums
    shelf['registrations_df_cnums_no_dates'] = registrations_df_cnums_no_dates
    shelf['registrations_df_cnums_dates'] = registrations_df_cnums_dates
    shelf['renewals_df'] = renewals_df
    shelf['renewals_df_cnums'] = renewals_df_cnums
    shelf['renewals_df_cleaned'] = renewals_df_cleaned

# %%
with shelve.open('shelf.p', 'r') as shelf:
    registrations_df = shelf['registrations_df']
    registrations_df_cnums = shelf['registrations_df_cnums']
    registrations_df_cnums_no_dates = shelf['registrations_df_cnums_no_dates']
    registrations_df_cnums_dates = shelf['registrations_df_cnums_dates']
    renewals_df = shelf['renewals_df']
    renewals_df_cnums = shelf['renewals_df_cnums']
    renewals_df_cleaned = shelf['renewals_df_cleaned']

# %% [markdown]
# # Another Sum-Up
#
# - **renewals_df** --> all renewal records
# - **renewals_df_cnums** --> all renewal records with control numbers
# - **renewals_df_cleaned** --> all renewal records with registration dates and registration control numbers (cdmid and cdmid_nd)

# %% [markdown]
# # Matching
# ## Pass One

# %%
# isolate renewals DF for cdmids
renewals_cdmid = renewals_df_cleaned[['uuid', 'cdmid']]
renewals_cdmid.rename(columns={"uuid": "renewal_uuid"}, inplace=True)
# Out:
# /home/scottythered/.local/lib/python3.6/site-packages/pandas/core/frame.py:4218: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)

# %%
renewals_cdmid.head()
# Out:
#                           renewal_uuid               cdmid
# 122   03609b71da864fcc9a6319e58782cb1c  A778640|1924-03-28
# 753   2af515ad21af405a94b45534ca94163a  B571853|1925-03-08
# 1057  ccc034a864fb40a68f099fafbbbddb96  A778640|1924-03-28
# 1105  2e0b51f7c4174e4db9c847386e3a0433   F42232|1925-04-10
# 1200  7f8d7aae0c504c41b27dc969a0cd4f2b   D64453|1925-05-12

# %%
# merge to match cdmids
registrations_df_cnums_dates.reset_index(drop=False, inplace=True)
cdmid_matches = registrations_df_cnums_dates.merge(renewals_cdmid, how='left', on='cdmid')
# drop all columns but the entry identifier for the renewals
cdmid_matches = cdmid_matches[['uuid', 'renewal_uuid']]
cdmid_matches.head()
# Out:
#                                uuid renewal_uuid
# 0  01627bce16d2467cbac4756963a8d883          NaN
# 1  f0b04f5841ae41d39963289a7894ec9d          NaN
# 2  9aeff066dcf94164b08a40fca354fd23          NaN
# 3  1a91f4c0842140ca91ae89548c9588f6          NaN
# 4  b751d06548b64ddaa24e0ba239e3f4b7          NaN

# %%
# drop any non-matches
cdmid_matches.dropna(subset=['renewal_uuid'], inplace=True)
len(cdmid_matches)
# Out:
# 136035

# %%
# any duplicate matches?
cdmid_matches['renewal_uuid'].duplicated().sum()
# Out:
# 249

# %%
cdmid_matches.drop_duplicates(keep='first', inplace=True)
len(cdmid_matches)
# Out:
# 136035

# %%
cdmid_matches.set_index('uuid', inplace=True)
cdmid_matches = cdmid_matches.groupby('uuid').agg(lambda x: '||'.join(x))
cdmid_matches.head(8)
# Out:
#                                                       renewal_uuid
# uuid
# 0000216a4b144f6db2117feca322d10d  bb7e105e6a8845ad9ec46448cf0cbb12
# 00002a28abd54484a6218aa170c4926b  052e4e69a2ec4e59ad8e84e1abe950b8
# 00004e0edc9144df8826d74bc84dad2d  b3b8b0cec07143fdb506412b471f60ac
# 00006f1e1b7241209a9d1d17144c00da  c03fba8c417342aca9c6554c2f1a9a37
# 00008a3e335d4742a021bc31b4fc6df5  e484d9fb69ec474ab7f07ec6fd1b34f9
# 0001197b605f4f6fad856f89d716a882  82c5fcd351c44685a2d627bdd6c9fb1d
# 00014352923245039e30a090369489a7  14ef3d9be34a477191bdbef7c8faca72
# 00020e8019c44cbbbc97355cf8a05a37  0b19e007a2e64d16b7f7e4e4964b3a6c

# %%
len(cdmid_matches)
# Out:
# 133661

# %% [markdown]
# ## Pass Two

# %%
# now let's do it all over for cdmid_nd's; but first, we need to get rid of all of our
# cdmid matches in the renewals data
renewals_matched_by_cdmid = cdmid_matches['renewal_uuid'].to_list()
renewals_matched_by_cdmid_split = [x for i in renewals_matched_by_cdmid for x in i.split('||')]

# %%
len(renewals_matched_by_cdmid)
# Out:
# 133661

# %%
len(renewals_matched_by_cdmid_split)
# Out:
# 136035

# %%
deduped_renewals_matched_by_cdmid = list(set(renewals_matched_by_cdmid_split))
len(deduped_renewals_matched_by_cdmid)
# Out:
# 135786

# %%
temp = pd.DataFrame(deduped_renewals_matched_by_cdmid)
temp['matched'] = 'yes'
temp.rename(columns={0: 'uuid'}, inplace=True)
temp.head()
# Out:
#                                uuid matched
# 0  fb4530f6a54947e2bd89e368072e01e3     yes
# 1  e998477206ea48b68d4cc4f39c285e7d     yes
# 2  c4892ba99c254cfe8d626e17a4a65957     yes
# 3  674e58464ff046039c12952a67239920     yes
# 4  017c54e6141f466ea7616460947c0ff6     yes

# %%
renewals_filtered = renewals_df_cleaned[['uuid', 'cdmid', 'cdmid_nd']]
len(renewals_filtered)
# Out:
# 434174

# %%
matches = renewals_filtered.merge(temp, how='left', on='uuid')
len(matches)
# Out:
# 434174

# %%
unmatched = matches[matches['matched'].isna()]
unmatched.head()
# Out:
#                                uuid               cdmid      cdmid_nd matched
# 0  03609b71da864fcc9a6319e58782cb1c  A778640|1924-03-28  A778640|1924     NaN
# 1  2af515ad21af405a94b45534ca94163a  B571853|1925-03-08  B571853|1925     NaN
# 2  ccc034a864fb40a68f099fafbbbddb96  A778640|1924-03-28  A778640|1924     NaN
# 3  2e0b51f7c4174e4db9c847386e3a0433   F42232|1925-04-10   F42232|1925     NaN
# 4  7f8d7aae0c504c41b27dc969a0cd4f2b   D64453|1925-05-12   D64453|1925     NaN

# %%
unmatched.drop(columns=['cdmid', 'matched'], inplace=True)
unmatched.rename(columns={"uuid": "renewal_uuid"}, inplace=True)
len(unmatched)
# Out:
# 298388

# %%
unmatched.head()
# Out:
#                        renewal_uuid      cdmid_nd
# 0  03609b71da864fcc9a6319e58782cb1c  A778640|1924
# 1  2af515ad21af405a94b45534ca94163a  B571853|1925
# 2  ccc034a864fb40a68f099fafbbbddb96  A778640|1924
# 3  2e0b51f7c4174e4db9c847386e3a0433   F42232|1925
# 4  7f8d7aae0c504c41b27dc969a0cd4f2b   D64453|1925

# %%
registrations_df_cnums_no_dates.reset_index(drop=False, inplace=True)
cdmid_nd_matches = registrations_df_cnums_no_dates.merge(unmatched, how='left', on='cdmid_nd')
# drop any non-matches
cdmid_nd_matches.dropna(subset=['renewal_uuid'], inplace=True)
len(cdmid_nd_matches)
# Out:
# 316

# %%
# any duplicate matches?
cdmid_nd_matches['renewal_uuid'].duplicated().sum()
# Out:
# 0

# %%
# drop all columns but the entry identifier for the renewals
cdmid_nd_matches = cdmid_nd_matches[['uuid', 'renewal_uuid']]
cdmid_nd_matches.set_index('uuid', inplace=True)
cdmid_nd_matches = cdmid_nd_matches.groupby('uuid').agg(lambda x: '||'.join(x))
cdmid_nd_matches.head(3)
# Out:
#                                                       renewal_uuid
# uuid
# 0195b8865ba14b8d9faa730ad9bf4b2e  46eece3c1cca4a9b9f74e51c15210911
# 022f141f894344b7970752f6de8e463a  cb7218f018fc4dff99f301a717eb0372
# 0256f16258304b9d9dc633f56453e200  3cca639078e949c0bc40b95e2fe4c168

# %%
len(cdmid_nd_matches)
# Out:
# 300

# %%
len(cdmid_matches)
# Out:
# 133661

# %%
((len(cdmid_nd_matches) + len(cdmid_matches)) / len(registrations_df)) * 100
# Out:
# 23.08450527048614

# %%
cdmid_nd_matches['match_method'] = 'cdmid_nd'
cdmid_matches['match_method'] = 'cdmid'

# %%
cdmid_nd_matches
# Out:
#                                                       renewal_uuid  \
# uuid
# 0195b8865ba14b8d9faa730ad9bf4b2e  46eece3c1cca4a9b9f74e51c15210911
# 022f141f894344b7970752f6de8e463a  cb7218f018fc4dff99f301a717eb0372
# 0256f16258304b9d9dc633f56453e200  3cca639078e949c0bc40b95e2fe4c168
# 051b328e522b45f5956507c6557256cc  94e71f6243474e559d7584494fc31023
# 0756c8a42eed466bb75614dc08512dcc  6ca7d4b18cbd4d9499563e5e957238d3
# ...                                                            ...
# faee2e1635eb4514aaf5325d72aa058a  6b8887f5c3604a8ca6f956395408d25c
# fbb829190942471490a5946e26011633  5a11e5cae1164941b33dc1a6d1a04b70
# fd416dec6f3841f59d4fa5da9ef5f889  febd933c56d8425d922504af5feed25a
# fe2343eca4684afc8091992dc9c94fc9  d7880c59799f4175967e3b47c7b3f3d4
# febb6a8a7ba0450eb705aceb3556004d  ee5453681e054e2db0e408c778913651
#
#                                  match_method
# uuid
# 0195b8865ba14b8d9faa730ad9bf4b2e     cdmid_nd
# 022f141f894344b7970752f6de8e463a     cdmid_nd
# 0256f16258304b9d9dc633f56453e200     cdmid_nd
# 051b328e522b45f5956507c6557256cc     cdmid_nd
# 0756c8a42eed466bb75614dc08512dcc     cdmid_nd
# ...                                       ...
# faee2e1635eb4514aaf5325d72aa058a     cdmid_nd
# fbb829190942471490a5946e26011633     cdmid_nd
# fd416dec6f3841f59d4fa5da9ef5f889     cdmid_nd
# fe2343eca4684afc8091992dc9c94fc9     cdmid_nd
# febb6a8a7ba0450eb705aceb3556004d     cdmid_nd
#
# [300 rows x 2 columns]

# %%
cdmid_matches
# Out:
#                                                       renewal_uuid  \
# uuid
# 0000216a4b144f6db2117feca322d10d  bb7e105e6a8845ad9ec46448cf0cbb12
# 00002a28abd54484a6218aa170c4926b  052e4e69a2ec4e59ad8e84e1abe950b8
# 00004e0edc9144df8826d74bc84dad2d  b3b8b0cec07143fdb506412b471f60ac
# 00006f1e1b7241209a9d1d17144c00da  c03fba8c417342aca9c6554c2f1a9a37
# 00008a3e335d4742a021bc31b4fc6df5  e484d9fb69ec474ab7f07ec6fd1b34f9
# ...                                                            ...
# ffff888709374316926b2113800a7d9e  05fd488bc8ee4a0db56078d82d0bca06
# ffffc8ca17634785847a2249cb574f8b  f1b70bbb5983441b812222375500d9a1
# ffffca4094044b44b88b6dad21c70d05  a180bf84f1c64144b225f997d5a24bd5
# ffffd22157994202b4e253afcca92191  ccc8a4f987614bcda4ae43497ed5d235
# ffffd51b95914b5eb374c477c9c7bb10  4683b31a20fe486984933a11aeeb5d79
#
#                                  match_method
# uuid
# 0000216a4b144f6db2117feca322d10d        cdmid
# 00002a28abd54484a6218aa170c4926b        cdmid
# 00004e0edc9144df8826d74bc84dad2d        cdmid
# 00006f1e1b7241209a9d1d17144c00da        cdmid
# 00008a3e335d4742a021bc31b4fc6df5        cdmid
# ...                                       ...
# ffff888709374316926b2113800a7d9e        cdmid
# ffffc8ca17634785847a2249cb574f8b        cdmid
# ffffca4094044b44b88b6dad21c70d05        cdmid
# ffffd22157994202b4e253afcca92191        cdmid
# ffffd51b95914b5eb374c477c9c7bb10        cdmid
#
# [133661 rows x 2 columns]

# %%
all_matches = pd.concat([cdmid_matches, cdmid_nd_matches])

# %%
len(all_matches) / len(registrations_df) * 100
# Out:
# 23.08450527048614

# %%
len(all_matches)
# Out:
# 133961
